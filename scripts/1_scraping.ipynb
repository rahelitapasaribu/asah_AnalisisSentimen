# %% [markdown]
# Import Library

# %%
import os 
import time
import json
import math
from datetime import datetime
from google_play_scraper import reviews, Sort
import pandas as pd
from tqdm.notebook import tqdm
from langdetect import detect, LangDetectException

# %% [markdown]
# Configuration

# %%
APP_ID = "com.gojek.app"
NUM_REVIEWS = 100000
BATCH_SIZE = 200
OUTPUT_DIR = "../data/raw"
BATCH_PREFIX = "gojek_reviews"
sleep_between_batches = 1.0  # seconds
max_retries = 5
lang_filter = "id"

# %%
os.makedirs(OUTPUT_DIR, exist_ok=True)

def language(text):
    if not text or not isinstance(text, str):
        return False
    try:
        lang = detect(text)
        return lang == lang_filter
    except LangDetectException:
        return False

# %%
def fetch_batch(continuation_token=None, count=BATCH_SIZE):
    for attempt in range(1, max_retries+1):
        try:
            result, next_token = reviews(
                APP_ID,
                lang="id",
                country="id",
                sort=Sort.NEWEST,
                count=count,
                continuation_token=continuation_token
            )
            return result, next_token
        except Exception as e:
            wait = 2 ** attempt
            print(f"Error fetching reviews: {e}. Retrying ({attempt + 1}/{max_retries})...")
            time.sleep(wait)
    raise RuntimeError("Max retries exceeded while fetching reviews.")

# %%
def review(r):
    return {
        "reviewId": r["reviewId"],
        "userName": r["userName"],
        "content": r["content"],
        "score": r["score"],
        "thumbsUpCount": r["thumbsUpCount"],
        "at": r["at"].isoformat(),
        "replyContent": r["replyContent"],
        "repliedAt": r["repliedAt"].isoformat() if r["repliedAt"] else None,
        "version": r["reviewCreatedVersion"]
    }

# %%
def save_batch(df, batch_idx):
    fname = os.path.join(OUTPUT_DIR, f"{BATCH_PREFIX}_{batch_idx:04d}.csv")
    df.to_csv(fname, index=False)
    print(f"Saved {len(df)} reviews to {fname}")

# %%
exist = sorted([f for f in os.listdir(OUTPUT_DIR) if f.startswith(BATCH_PREFIX) and f.endswith(".csv")])
if exist:
    last_batch = exist[-1]
    batch_idx = int(last_batch.replace(BATCH_PREFIX + "_", "").replace(".csv", ""))
    count_scraped = sum(pd.read_csv(os.path.join(OUTPUT_DIR, f)).shape[0] for f in exist)
    print(f"Found {len(exist)} existing batches, last batch index {batch_idx}, total reviews scraped {count_scraped}")
    start_batch_idx = batch_idx + 1
else:
    count_scraped = 0
    start_batch_idx = 0
    print("No existing batches found, starting fresh.")
# Out:
# No existing batches found, starting fresh.

# %%
continuation_token = None
batch_idx = start_batch_idx
pbar = tqdm(total=NUM_REVIEWS, initial=count_scraped, desc="Scraping Reviews")
while count_scraped < NUM_REVIEWS:
    try:
        items, continuation_token = fetch_batch(continuation_token, BATCH_SIZE)
    except RuntimeError as e:
        print(e)
        break
    normalized = []
    for it in items:
        rec = review(it)
        if lang_filter:
            content = rec["content"] or ""
            if content.strip() == "":
                continue
            if language(content):
                normalized.append(rec)
        else:
            normalized.append(rec)

    if len(normalized) == 0:
        print("No reviews in the desired language found in this batch, stopping.")
        break

    df_batch = pd.DataFrame(normalized)
    save_batch(df_batch, batch_idx)
    count_scraped += len(df_batch)
    pbar.update(len(df_batch))
    batch_idx += 1
    time.sleep(sleep_between_batches)

    if not continuation_token:
        print("No more continuation token, reached the end of reviews.")
        break

pbar.close()
print(f"Scraping completed. Total reviews scraped: {count_scraped}")
# Out:
# Scraping Reviews:   0%|          | 0/100000 [00:00<?, ?it/s]
# Saved 132 reviews to ../data/raw\gojek_reviews_0000.csv
# Saved 139 reviews to ../data/raw\gojek_reviews_0001.csv
# Saved 147 reviews to ../data/raw\gojek_reviews_0002.csv
# Saved 137 reviews to ../data/raw\gojek_reviews_0003.csv
# Saved 136 reviews to ../data/raw\gojek_reviews_0004.csv
# Saved 155 reviews to ../data/raw\gojek_reviews_0005.csv
# Saved 136 reviews to ../data/raw\gojek_reviews_0006.csv
# Saved 141 reviews to ../data/raw\gojek_reviews_0007.csv
# Saved 142 reviews to ../data/raw\gojek_reviews_0008.csv
# Saved 125 reviews to ../data/raw\gojek_reviews_0009.csv
# Saved 129 reviews to ../data/raw\gojek_reviews_0010.csv
# Saved 132 reviews to ../data/raw\gojek_reviews_0011.csv
# Saved 121 reviews to ../data/raw\gojek_reviews_0012.csv
# Saved 141 reviews to ../data/raw\gojek_reviews_0013.csv
# Saved 150 reviews to ../data/raw\gojek_reviews_0014.csv
# Saved 141 reviews to ../data/raw\gojek_reviews_0015.csv
# Saved 122 reviews to ../data/raw\gojek_reviews_0016.csv
# Saved 149 reviews to ../data/raw\gojek_reviews_0017.csv
# Saved 133 reviews to ../data/raw\gojek_reviews_0018.csv
# Saved 135 reviews to ../data/raw\gojek_reviews_0019.csv
# Saved 131 reviews to ../data/raw\gojek_reviews_0020.csv
# Saved 126 reviews to ../data/raw\gojek_reviews_0021.csv
# Saved 125 reviews to ../data/raw\gojek_reviews_0022.csv
# Saved 129 reviews to ../data/raw\gojek_reviews_0023.csv
# Saved 131 reviews to ../data/raw\gojek_reviews_0024.csv
# Saved 137 reviews to ../data/raw\gojek_reviews_0025.csv
# Saved 130 reviews to ../data/raw\gojek_reviews_0026.csv
# Saved 132 reviews to ../data/raw\gojek_reviews_0027.csv
# Saved 135 reviews to ../data/raw\gojek_reviews_0028.csv
# Saved 132 reviews to ../data/raw\gojek_reviews_0029.csv
# Saved 123 reviews to ../data/raw\gojek_reviews_0030.csv
# Saved 133 reviews to ../data/raw\gojek_reviews_0031.csv
# Saved 124 reviews to ../data/raw\gojek_reviews_0032.csv
# Saved 123 reviews to ../data/raw\gojek_reviews_0033.csv
# Saved 122 reviews to ../data/raw\gojek_reviews_0034.csv
# Saved 132 reviews to ../data/raw\gojek_reviews_0035.csv
# Saved 135 reviews to ../data/raw\gojek_reviews_0036.csv
# Saved 121 reviews to ../data/raw\gojek_reviews_0037.csv
# Saved 137 reviews to ../data/raw\gojek_reviews_0038.csv
# Saved 132 reviews to ../data/raw\gojek_reviews_0039.csv
# Saved 122 reviews to ../data/raw\gojek_reviews_0040.csv
# Saved 142 reviews to ../data/raw\gojek_reviews_0041.csv
# Saved 126 reviews to ../data/raw\gojek_reviews_0042.csv
# Saved 135 reviews to ../data/raw\gojek_reviews_0043.csv
# Saved 143 reviews to ../data/raw\gojek_reviews_0044.csv
# Saved 138 reviews to ../data/raw\gojek_reviews_0045.csv
# Saved 138 reviews to ../data/raw\gojek_reviews_0046.csv
# Saved 131 reviews to ../data/raw\gojek_reviews_0047.csv
# Saved 131 reviews to ../data/raw\gojek_reviews_0048.csv
# Saved 141 reviews to ../data/raw\gojek_reviews_0049.csv
# Saved 136 reviews to ../data/raw\gojek_reviews_0050.csv
# Saved 167 reviews to ../data/raw\gojek_reviews_0051.csv
# Saved 145 reviews to ../data/raw\gojek_reviews_0052.csv
# Saved 129 reviews to ../data/raw\gojek_reviews_0053.csv
# Saved 139 reviews to ../data/raw\gojek_reviews_0054.csv
# Saved 137 reviews to ../data/raw\gojek_reviews_0055.csv
# Saved 144 reviews to ../data/raw\gojek_reviews_0056.csv
# Saved 130 reviews to ../data/raw\gojek_reviews_0057.csv
# Saved 134 reviews to ../data/raw\gojek_reviews_0058.csv
# Saved 131 reviews to ../data/raw\gojek_reviews_0059.csv
# Saved 144 reviews to ../data/raw\gojek_reviews_0060.csv
# Saved 129 reviews to ../data/raw\gojek_reviews_0061.csv
# Saved 127 reviews to ../data/raw\gojek_reviews_0062.csv
# Saved 134 reviews to ../data/raw\gojek_reviews_0063.csv
# Saved 133 reviews to ../data/raw\gojek_reviews_0064.csv
# Saved 141 reviews to ../data/raw\gojek_reviews_0065.csv
# Saved 126 reviews to ../data/raw\gojek_reviews_0066.csv
# Saved 133 reviews to ../data/raw\gojek_reviews_0067.csv
# Saved 118 reviews to ../data/raw\gojek_reviews_0068.csv
# Saved 135 reviews to ../data/raw\gojek_reviews_0069.csv
# Saved 113 reviews to ../data/raw\gojek_reviews_0070.csv
# Saved 128 reviews to ../data/raw\gojek_reviews_0071.csv
# Saved 143 reviews to ../data/raw\gojek_reviews_0072.csv
# Saved 124 reviews to ../data/raw\gojek_reviews_0073.csv
# Saved 135 reviews to ../data/raw\gojek_reviews_0074.csv
# Saved 136 reviews to ../data/raw\gojek_reviews_0075.csv
# Saved 131 reviews to ../data/raw\gojek_reviews_0076.csv
# Saved 132 reviews to ../data/raw\gojek_reviews_0077.csv
# Saved 136 reviews to ../data/raw\gojek_reviews_0078.csv
# Saved 137 reviews to ../data/raw\gojek_reviews_0079.csv
# Saved 132 reviews to ../data/raw\gojek_reviews_0080.csv
# Saved 130 reviews to ../data/raw\gojek_reviews_0081.csv
# Saved 138 reviews to ../data/raw\gojek_reviews_0082.csv
# Saved 120 reviews to ../data/raw\gojek_reviews_0083.csv
# Saved 129 reviews to ../data/raw\gojek_reviews_0084.csv
# Saved 122 reviews to ../data/raw\gojek_reviews_0085.csv
# Saved 128 reviews to ../data/raw\gojek_reviews_0086.csv
# Saved 117 reviews to ../data/raw\gojek_reviews_0087.csv
# Saved 124 reviews to ../data/raw\gojek_reviews_0088.csv
# Saved 140 reviews to ../data/raw\gojek_reviews_0089.csv
# Saved 129 reviews to ../data/raw\gojek_reviews_0090.csv
# Saved 121 reviews to ../data/raw\gojek_reviews_0091.csv
# Saved 118 reviews to ../data/raw\gojek_reviews_0092.csv
# Saved 136 reviews to ../data/raw\gojek_reviews_0093.csv
# Saved 131 reviews to ../data/raw\gojek_reviews_0094.csv
# Saved 135 reviews to ../data/raw\gojek_reviews_0095.csv
# Saved 133 reviews to ../data/raw\gojek_reviews_0096.csv
# Saved 128 reviews to ../data/raw\gojek_reviews_0097.csv
# Saved 118 reviews to ../data/raw\gojek_reviews_0098.csv
# Saved 134 reviews to ../data/raw\gojek_reviews_0099.csv
# Saved 125 reviews to ../data/raw\gojek_reviews_0100.csv
# Saved 128 reviews to ../data/raw\gojek_reviews_0101.csv
# Saved 132 reviews to ../data/raw\gojek_reviews_0102.csv
# Saved 134 reviews to ../data/raw\gojek_reviews_0103.csv
# Saved 118 reviews to ../data/raw\gojek_reviews_0104.csv
# Saved 133 reviews to ../data/raw\gojek_reviews_0105.csv
# Saved 128 reviews to ../data/raw\gojek_reviews_0106.csv
# Saved 130 reviews to ../data/raw\gojek_reviews_0107.csv
# Saved 133 reviews to ../data/raw\gojek_reviews_0108.csv
# Saved 128 reviews to ../data/raw\gojek_reviews_0109.csv
# Saved 121 reviews to ../data/raw\gojek_reviews_0110.csv
# Saved 129 reviews to ../data/raw\gojek_reviews_0111.csv
# Saved 122 reviews to ../data/raw\gojek_reviews_0112.csv
# Saved 118 reviews to ../data/raw\gojek_reviews_0113.csv
# Saved 131 reviews to ../data/raw\gojek_reviews_0114.csv
# Saved 142 reviews to ../data/raw\gojek_reviews_0115.csv
# Saved 115 reviews to ../data/raw\gojek_reviews_0116.csv
# Saved 121 reviews to ../data/raw\gojek_reviews_0117.csv
# Saved 142 reviews to ../data/raw\gojek_reviews_0118.csv
# Saved 123 reviews to ../data/raw\gojek_reviews_0119.csv
# Saved 133 reviews to ../data/raw\gojek_reviews_0120.csv
# Saved 128 reviews to ../data/raw\gojek_reviews_0121.csv
# Saved 121 reviews to ../data/raw\gojek_reviews_0122.csv
# Saved 115 reviews to ../data/raw\gojek_reviews_0123.csv
# Saved 126 reviews to ../data/raw\gojek_reviews_0124.csv
# Saved 133 reviews to ../data/raw\gojek_reviews_0125.csv
# Saved 117 reviews to ../data/raw\gojek_reviews_0126.csv
# Saved 132 reviews to ../data/raw\gojek_reviews_0127.csv
# Saved 132 reviews to ../data/raw\gojek_reviews_0128.csv
# Saved 136 reviews to ../data/raw\gojek_reviews_0129.csv
# Saved 128 reviews to ../data/raw\gojek_reviews_0130.csv
# Saved 128 reviews to ../data/raw\gojek_reviews_0131.csv
# Saved 120 reviews to ../data/raw\gojek_reviews_0132.csv
# Saved 128 reviews to ../data/raw\gojek_reviews_0133.csv
# Saved 132 reviews to ../data/raw\gojek_reviews_0134.csv
# Saved 128 reviews to ../data/raw\gojek_reviews_0135.csv
# Saved 131 reviews to ../data/raw\gojek_reviews_0136.csv
# Saved 145 reviews to ../data/raw\gojek_reviews_0137.csv
# Saved 145 reviews to ../data/raw\gojek_reviews_0138.csv
# Saved 127 reviews to ../data/raw\gojek_reviews_0139.csv
# Saved 115 reviews to ../data/raw\gojek_reviews_0140.csv
# Saved 137 reviews to ../data/raw\gojek_reviews_0141.csv
# Saved 134 reviews to ../data/raw\gojek_reviews_0142.csv
# Saved 132 reviews to ../data/raw\gojek_reviews_0143.csv
# Saved 139 reviews to ../data/raw\gojek_reviews_0144.csv
# Saved 130 reviews to ../data/raw\gojek_reviews_0145.csv
# Saved 123 reviews to ../data/raw\gojek_reviews_0146.csv
# Saved 138 reviews to ../data/raw\gojek_reviews_0147.csv
# Saved 141 reviews to ../data/raw\gojek_reviews_0148.csv
# Saved 137 reviews to ../data/raw\gojek_reviews_0149.csv
# Saved 136 reviews to ../data/raw\gojek_reviews_0150.csv
# Saved 160 reviews to ../data/raw\gojek_reviews_0151.csv
# Saved 141 reviews to ../data/raw\gojek_reviews_0152.csv
# Saved 135 reviews to ../data/raw\gojek_reviews_0153.csv
# Saved 130 reviews to ../data/raw\gojek_reviews_0154.csv
# Saved 161 reviews to ../data/raw\gojek_reviews_0155.csv
# Saved 153 reviews to ../data/raw\gojek_reviews_0156.csv
# Saved 151 reviews to ../data/raw\gojek_reviews_0157.csv
# Saved 140 reviews to ../data/raw\gojek_reviews_0158.csv
# Saved 145 reviews to ../data/raw\gojek_reviews_0159.csv
# Saved 143 reviews to ../data/raw\gojek_reviews_0160.csv
# Saved 132 reviews to ../data/raw\gojek_reviews_0161.csv
# Saved 133 reviews to ../data/raw\gojek_reviews_0162.csv
# Saved 122 reviews to ../data/raw\gojek_reviews_0163.csv
# Saved 131 reviews to ../data/raw\gojek_reviews_0164.csv
# Saved 143 reviews to ../data/raw\gojek_reviews_0165.csv
# Saved 137 reviews to ../data/raw\gojek_reviews_0166.csv
# Saved 131 reviews to ../data/raw\gojek_reviews_0167.csv
# Saved 142 reviews to ../data/raw\gojek_reviews_0168.csv
# Saved 134 reviews to ../data/raw\gojek_reviews_0169.csv
# Saved 135 reviews to ../data/raw\gojek_reviews_0170.csv
# Saved 137 reviews to ../data/raw\gojek_reviews_0171.csv
# Saved 118 reviews to ../data/raw\gojek_reviews_0172.csv
# Saved 145 reviews to ../data/raw\gojek_reviews_0173.csv
# Saved 130 reviews to ../data/raw\gojek_reviews_0174.csv
# Saved 141 reviews to ../data/raw\gojek_reviews_0175.csv
# Saved 135 reviews to ../data/raw\gojek_reviews_0176.csv
# Saved 140 reviews to ../data/raw\gojek_reviews_0177.csv
# Saved 136 reviews to ../data/raw\gojek_reviews_0178.csv
# Saved 138 reviews to ../data/raw\gojek_reviews_0179.csv
# Saved 140 reviews to ../data/raw\gojek_reviews_0180.csv
# Saved 152 reviews to ../data/raw\gojek_reviews_0181.csv
# Saved 132 reviews to ../data/raw\gojek_reviews_0182.csv
# Saved 142 reviews to ../data/raw\gojek_reviews_0183.csv
# Saved 135 reviews to ../data/raw\gojek_reviews_0184.csv
# Saved 149 reviews to ../data/raw\gojek_reviews_0185.csv
# Saved 167 reviews to ../data/raw\gojek_reviews_0186.csv
# Saved 152 reviews to ../data/raw\gojek_reviews_0187.csv
# Saved 143 reviews to ../data/raw\gojek_reviews_0188.csv
# Saved 137 reviews to ../data/raw\gojek_reviews_0189.csv
# Saved 142 reviews to ../data/raw\gojek_reviews_0190.csv
# Saved 139 reviews to ../data/raw\gojek_reviews_0191.csv
# Saved 140 reviews to ../data/raw\gojek_reviews_0192.csv
# Saved 134 reviews to ../data/raw\gojek_reviews_0193.csv
# Saved 138 reviews to ../data/raw\gojek_reviews_0194.csv
# Saved 135 reviews to ../data/raw\gojek_reviews_0195.csv
# Saved 137 reviews to ../data/raw\gojek_reviews_0196.csv
# Saved 136 reviews to ../data/raw\gojek_reviews_0197.csv
# Saved 146 reviews to ../data/raw\gojek_reviews_0198.csv
# Saved 141 reviews to ../data/raw\gojek_reviews_0199.csv
# Saved 135 reviews to ../data/raw\gojek_reviews_0200.csv
# Saved 143 reviews to ../data/raw\gojek_reviews_0201.csv
# Saved 133 reviews to ../data/raw\gojek_reviews_0202.csv
# Saved 153 reviews to ../data/raw\gojek_reviews_0203.csv
# Saved 143 reviews to ../data/raw\gojek_reviews_0204.csv
# Saved 141 reviews to ../data/raw\gojek_reviews_0205.csv
# Saved 140 reviews to ../data/raw\gojek_reviews_0206.csv
# Saved 135 reviews to ../data/raw\gojek_reviews_0207.csv
# Saved 138 reviews to ../data/raw\gojek_reviews_0208.csv
# Saved 141 reviews to ../data/raw\gojek_reviews_0209.csv
# Saved 151 reviews to ../data/raw\gojek_reviews_0210.csv
# Saved 141 reviews to ../data/raw\gojek_reviews_0211.csv
# Saved 146 reviews to ../data/raw\gojek_reviews_0212.csv
# Saved 134 reviews to ../data/raw\gojek_reviews_0213.csv
# Saved 142 reviews to ../data/raw\gojek_reviews_0214.csv
# Saved 139 reviews to ../data/raw\gojek_reviews_0215.csv
# Saved 147 reviews to ../data/raw\gojek_reviews_0216.csv
# Saved 145 reviews to ../data/raw\gojek_reviews_0217.csv
# Saved 140 reviews to ../data/raw\gojek_reviews_0218.csv
# Saved 139 reviews to ../data/raw\gojek_reviews_0219.csv
# Saved 135 reviews to ../data/raw\gojek_reviews_0220.csv
# Saved 148 reviews to ../data/raw\gojek_reviews_0221.csv
# Saved 139 reviews to ../data/raw\gojek_reviews_0222.csv
# Saved 137 reviews to ../data/raw\gojek_reviews_0223.csv
# Saved 145 reviews to ../data/raw\gojek_reviews_0224.csv
# Saved 133 reviews to ../data/raw\gojek_reviews_0225.csv
# Saved 164 reviews to ../data/raw\gojek_reviews_0226.csv
# Saved 151 reviews to ../data/raw\gojek_reviews_0227.csv
# Saved 136 reviews to ../data/raw\gojek_reviews_0228.csv
# Saved 139 reviews to ../data/raw\gojek_reviews_0229.csv
# Saved 133 reviews to ../data/raw\gojek_reviews_0230.csv
# Saved 132 reviews to ../data/raw\gojek_reviews_0231.csv
# Saved 138 reviews to ../data/raw\gojek_reviews_0232.csv
# Saved 134 reviews to ../data/raw\gojek_reviews_0233.csv
# Saved 150 reviews to ../data/raw\gojek_reviews_0234.csv
# Saved 145 reviews to ../data/raw\gojek_reviews_0235.csv
# Saved 146 reviews to ../data/raw\gojek_reviews_0236.csv
# Saved 134 reviews to ../data/raw\gojek_reviews_0237.csv
# Saved 143 reviews to ../data/raw\gojek_reviews_0238.csv
# Saved 132 reviews to ../data/raw\gojek_reviews_0239.csv
# Saved 125 reviews to ../data/raw\gojek_reviews_0240.csv
# Saved 140 reviews to ../data/raw\gojek_reviews_0241.csv
# Saved 137 reviews to ../data/raw\gojek_reviews_0242.csv
# Saved 138 reviews to ../data/raw\gojek_reviews_0243.csv
# Saved 146 reviews to ../data/raw\gojek_reviews_0244.csv
# Saved 140 reviews to ../data/raw\gojek_reviews_0245.csv
# Saved 148 reviews to ../data/raw\gojek_reviews_0246.csv
# Saved 125 reviews to ../data/raw\gojek_reviews_0247.csv
# Saved 139 reviews to ../data/raw\gojek_reviews_0248.csv
# Saved 146 reviews to ../data/raw\gojek_reviews_0249.csv
# Saved 150 reviews to ../data/raw\gojek_reviews_0250.csv
# Saved 144 reviews to ../data/raw\gojek_reviews_0251.csv
# Saved 154 reviews to ../data/raw\gojek_reviews_0252.csv
# Saved 147 reviews to ../data/raw\gojek_reviews_0253.csv
# Saved 143 reviews to ../data/raw\gojek_reviews_0254.csv
# Saved 144 reviews to ../data/raw\gojek_reviews_0255.csv
# Saved 153 reviews to ../data/raw\gojek_reviews_0256.csv
# Saved 142 reviews to ../data/raw\gojek_reviews_0257.csv
# Saved 149 reviews to ../data/raw\gojek_reviews_0258.csv
# Saved 150 reviews to ../data/raw\gojek_reviews_0259.csv
# Saved 137 reviews to ../data/raw\gojek_reviews_0260.csv
# Saved 139 reviews to ../data/raw\gojek_reviews_0261.csv
# Saved 128 reviews to ../data/raw\gojek_reviews_0262.csv
# Saved 158 reviews to ../data/raw\gojek_reviews_0263.csv
# Saved 148 reviews to ../data/raw\gojek_reviews_0264.csv
# Saved 138 reviews to ../data/raw\gojek_reviews_0265.csv
# Saved 137 reviews to ../data/raw\gojek_reviews_0266.csv
# Saved 140 reviews to ../data/raw\gojek_reviews_0267.csv
# Saved 144 reviews to ../data/raw\gojek_reviews_0268.csv
# Saved 147 reviews to ../data/raw\gojek_reviews_0269.csv
# Saved 142 reviews to ../data/raw\gojek_reviews_0270.csv
# Saved 139 reviews to ../data/raw\gojek_reviews_0271.csv
# Saved 153 reviews to ../data/raw\gojek_reviews_0272.csv
# Saved 141 reviews to ../data/raw\gojek_reviews_0273.csv
# Saved 143 reviews to ../data/raw\gojek_reviews_0274.csv
# Saved 137 reviews to ../data/raw\gojek_reviews_0275.csv
# Saved 136 reviews to ../data/raw\gojek_reviews_0276.csv
# Saved 133 reviews to ../data/raw\gojek_reviews_0277.csv
# Saved 141 reviews to ../data/raw\gojek_reviews_0278.csv
# Saved 141 reviews to ../data/raw\gojek_reviews_0279.csv
# Saved 156 reviews to ../data/raw\gojek_reviews_0280.csv
# Saved 140 reviews to ../data/raw\gojek_reviews_0281.csv
# Saved 158 reviews to ../data/raw\gojek_reviews_0282.csv
# Saved 141 reviews to ../data/raw\gojek_reviews_0283.csv
# Saved 145 reviews to ../data/raw\gojek_reviews_0284.csv
# Saved 145 reviews to ../data/raw\gojek_reviews_0285.csv
# Saved 131 reviews to ../data/raw\gojek_reviews_0286.csv
# Saved 145 reviews to ../data/raw\gojek_reviews_0287.csv
# Saved 144 reviews to ../data/raw\gojek_reviews_0288.csv
# Saved 138 reviews to ../data/raw\gojek_reviews_0289.csv
# Saved 146 reviews to ../data/raw\gojek_reviews_0290.csv
# Saved 139 reviews to ../data/raw\gojek_reviews_0291.csv
# Saved 134 reviews to ../data/raw\gojek_reviews_0292.csv
# Saved 136 reviews to ../data/raw\gojek_reviews_0293.csv
# Saved 143 reviews to ../data/raw\gojek_reviews_0294.csv
# Saved 137 reviews to ../data/raw\gojek_reviews_0295.csv
# Saved 139 reviews to ../data/raw\gojek_reviews_0296.csv
# Saved 133 reviews to ../data/raw\gojek_reviews_0297.csv
# Saved 136 reviews to ../data/raw\gojek_reviews_0298.csv
# Saved 150 reviews to ../data/raw\gojek_reviews_0299.csv
# Saved 133 reviews to ../data/raw\gojek_reviews_0300.csv
# Saved 135 reviews to ../data/raw\gojek_reviews_0301.csv
# Saved 141 reviews to ../data/raw\gojek_reviews_0302.csv
# Saved 151 reviews to ../data/raw\gojek_reviews_0303.csv
# Saved 133 reviews to ../data/raw\gojek_reviews_0304.csv
# Saved 143 reviews to ../data/raw\gojek_reviews_0305.csv
# Saved 138 reviews to ../data/raw\gojek_reviews_0306.csv
# Saved 152 reviews to ../data/raw\gojek_reviews_0307.csv
# Saved 145 reviews to ../data/raw\gojek_reviews_0308.csv
# Saved 142 reviews to ../data/raw\gojek_reviews_0309.csv
# Saved 148 reviews to ../data/raw\gojek_reviews_0310.csv
# Saved 141 reviews to ../data/raw\gojek_reviews_0311.csv
# Saved 147 reviews to ../data/raw\gojek_reviews_0312.csv
# Saved 147 reviews to ../data/raw\gojek_reviews_0313.csv
# Saved 130 reviews to ../data/raw\gojek_reviews_0314.csv
# Saved 133 reviews to ../data/raw\gojek_reviews_0315.csv
# Saved 152 reviews to ../data/raw\gojek_reviews_0316.csv
# Saved 142 reviews to ../data/raw\gojek_reviews_0317.csv
# Saved 140 reviews to ../data/raw\gojek_reviews_0318.csv
# Saved 142 reviews to ../data/raw\gojek_reviews_0319.csv
# Saved 147 reviews to ../data/raw\gojek_reviews_0320.csv
# Saved 146 reviews to ../data/raw\gojek_reviews_0321.csv
# Saved 143 reviews to ../data/raw\gojek_reviews_0322.csv
# Saved 131 reviews to ../data/raw\gojek_reviews_0323.csv
# Saved 138 reviews to ../data/raw\gojek_reviews_0324.csv
# Saved 142 reviews to ../data/raw\gojek_reviews_0325.csv
# Saved 143 reviews to ../data/raw\gojek_reviews_0326.csv
# Saved 138 reviews to ../data/raw\gojek_reviews_0327.csv
# Saved 139 reviews to ../data/raw\gojek_reviews_0328.csv
# Saved 133 reviews to ../data/raw\gojek_reviews_0329.csv
# Saved 149 reviews to ../data/raw\gojek_reviews_0330.csv
# Saved 131 reviews to ../data/raw\gojek_reviews_0331.csv
# Saved 141 reviews to ../data/raw\gojek_reviews_0332.csv
# Saved 140 reviews to ../data/raw\gojek_reviews_0333.csv
# Saved 131 reviews to ../data/raw\gojek_reviews_0334.csv
# Saved 124 reviews to ../data/raw\gojek_reviews_0335.csv
# Saved 127 reviews to ../data/raw\gojek_reviews_0336.csv
# Saved 144 reviews to ../data/raw\gojek_reviews_0337.csv
# Saved 128 reviews to ../data/raw\gojek_reviews_0338.csv
# Saved 141 reviews to ../data/raw\gojek_reviews_0339.csv
# Saved 143 reviews to ../data/raw\gojek_reviews_0340.csv
# Saved 137 reviews to ../data/raw\gojek_reviews_0341.csv
# Saved 134 reviews to ../data/raw\gojek_reviews_0342.csv
# Saved 137 reviews to ../data/raw\gojek_reviews_0343.csv
# Saved 135 reviews to ../data/raw\gojek_reviews_0344.csv
# Saved 140 reviews to ../data/raw\gojek_reviews_0345.csv
# Saved 139 reviews to ../data/raw\gojek_reviews_0346.csv
# Saved 129 reviews to ../data/raw\gojek_reviews_0347.csv
# Saved 137 reviews to ../data/raw\gojek_reviews_0348.csv
# Saved 128 reviews to ../data/raw\gojek_reviews_0349.csv
# Saved 136 reviews to ../data/raw\gojek_reviews_0350.csv
# Saved 124 reviews to ../data/raw\gojek_reviews_0351.csv
# Saved 140 reviews to ../data/raw\gojek_reviews_0352.csv
# Saved 138 reviews to ../data/raw\gojek_reviews_0353.csv
# Saved 136 reviews to ../data/raw\gojek_reviews_0354.csv
# Saved 148 reviews to ../data/raw\gojek_reviews_0355.csv
# Saved 129 reviews to ../data/raw\gojek_reviews_0356.csv
# Saved 136 reviews to ../data/raw\gojek_reviews_0357.csv
# Saved 133 reviews to ../data/raw\gojek_reviews_0358.csv
# Saved 120 reviews to ../data/raw\gojek_reviews_0359.csv
# Saved 136 reviews to ../data/raw\gojek_reviews_0360.csv
# Saved 119 reviews to ../data/raw\gojek_reviews_0361.csv
# Saved 132 reviews to ../data/raw\gojek_reviews_0362.csv
# Saved 141 reviews to ../data/raw\gojek_reviews_0363.csv
# Saved 126 reviews to ../data/raw\gojek_reviews_0364.csv
# Saved 144 reviews to ../data/raw\gojek_reviews_0365.csv
# Saved 145 reviews to ../data/raw\gojek_reviews_0366.csv
# Saved 135 reviews to ../data/raw\gojek_reviews_0367.csv
# Saved 122 reviews to ../data/raw\gojek_reviews_0368.csv
# Saved 134 reviews to ../data/raw\gojek_reviews_0369.csv
# Saved 126 reviews to ../data/raw\gojek_reviews_0370.csv
# Saved 138 reviews to ../data/raw\gojek_reviews_0371.csv
# Saved 124 reviews to ../data/raw\gojek_reviews_0372.csv
# Saved 131 reviews to ../data/raw\gojek_reviews_0373.csv
# Saved 123 reviews to ../data/raw\gojek_reviews_0374.csv
# Saved 140 reviews to ../data/raw\gojek_reviews_0375.csv
# Saved 143 reviews to ../data/raw\gojek_reviews_0376.csv
# Saved 137 reviews to ../data/raw\gojek_reviews_0377.csv
# Saved 136 reviews to ../data/raw\gojek_reviews_0378.csv
# Saved 137 reviews to ../data/raw\gojek_reviews_0379.csv
# Saved 135 reviews to ../data/raw\gojek_reviews_0380.csv
# Saved 128 reviews to ../data/raw\gojek_reviews_0381.csv
# Saved 139 reviews to ../data/raw\gojek_reviews_0382.csv
# Saved 134 reviews to ../data/raw\gojek_reviews_0383.csv
# Saved 126 reviews to ../data/raw\gojek_reviews_0384.csv
# Saved 133 reviews to ../data/raw\gojek_reviews_0385.csv
# Saved 134 reviews to ../data/raw\gojek_reviews_0386.csv
# Saved 123 reviews to ../data/raw\gojek_reviews_0387.csv
# Saved 131 reviews to ../data/raw\gojek_reviews_0388.csv
# Saved 128 reviews to ../data/raw\gojek_reviews_0389.csv
# Saved 144 reviews to ../data/raw\gojek_reviews_0390.csv
# Saved 123 reviews to ../data/raw\gojek_reviews_0391.csv
# Saved 121 reviews to ../data/raw\gojek_reviews_0392.csv
# Saved 139 reviews to ../data/raw\gojek_reviews_0393.csv
# Saved 131 reviews to ../data/raw\gojek_reviews_0394.csv
# Saved 141 reviews to ../data/raw\gojek_reviews_0395.csv
# Saved 146 reviews to ../data/raw\gojek_reviews_0396.csv
# Saved 134 reviews to ../data/raw\gojek_reviews_0397.csv
# Saved 139 reviews to ../data/raw\gojek_reviews_0398.csv
# Saved 144 reviews to ../data/raw\gojek_reviews_0399.csv
# Saved 136 reviews to ../data/raw\gojek_reviews_0400.csv
# Saved 140 reviews to ../data/raw\gojek_reviews_0401.csv
# Saved 126 reviews to ../data/raw\gojek_reviews_0402.csv
# Saved 140 reviews to ../data/raw\gojek_reviews_0403.csv
# Saved 137 reviews to ../data/raw\gojek_reviews_0404.csv
# Saved 133 reviews to ../data/raw\gojek_reviews_0405.csv
# Saved 120 reviews to ../data/raw\gojek_reviews_0406.csv
# Saved 135 reviews to ../data/raw\gojek_reviews_0407.csv
# Saved 135 reviews to ../data/raw\gojek_reviews_0408.csv
# Saved 132 reviews to ../data/raw\gojek_reviews_0409.csv
# Saved 136 reviews to ../data/raw\gojek_reviews_0410.csv
# Saved 123 reviews to ../data/raw\gojek_reviews_0411.csv
# Saved 132 reviews to ../data/raw\gojek_reviews_0412.csv
# Saved 146 reviews to ../data/raw\gojek_reviews_0413.csv
# Saved 145 reviews to ../data/raw\gojek_reviews_0414.csv
# Saved 131 reviews to ../data/raw\gojek_reviews_0415.csv
# Saved 135 reviews to ../data/raw\gojek_reviews_0416.csv
# Saved 150 reviews to ../data/raw\gojek_reviews_0417.csv
# Saved 129 reviews to ../data/raw\gojek_reviews_0418.csv
# Saved 142 reviews to ../data/raw\gojek_reviews_0419.csv
# Saved 132 reviews to ../data/raw\gojek_reviews_0420.csv
# Saved 133 reviews to ../data/raw\gojek_reviews_0421.csv
# Saved 136 reviews to ../data/raw\gojek_reviews_0422.csv
# Saved 142 reviews to ../data/raw\gojek_reviews_0423.csv
# Saved 142 reviews to ../data/raw\gojek_reviews_0424.csv
# Saved 138 reviews to ../data/raw\gojek_reviews_0425.csv
# Saved 145 reviews to ../data/raw\gojek_reviews_0426.csv
# Saved 127 reviews to ../data/raw\gojek_reviews_0427.csv
# Saved 132 reviews to ../data/raw\gojek_reviews_0428.csv
# Saved 137 reviews to ../data/raw\gojek_reviews_0429.csv
# Saved 137 reviews to ../data/raw\gojek_reviews_0430.csv
# Saved 129 reviews to ../data/raw\gojek_reviews_0431.csv
# Saved 135 reviews to ../data/raw\gojek_reviews_0432.csv
# Saved 143 reviews to ../data/raw\gojek_reviews_0433.csv
# Saved 137 reviews to ../data/raw\gojek_reviews_0434.csv
# Saved 130 reviews to ../data/raw\gojek_reviews_0435.csv
# Saved 125 reviews to ../data/raw\gojek_reviews_0436.csv
# Saved 133 reviews to ../data/raw\gojek_reviews_0437.csv
# Saved 126 reviews to ../data/raw\gojek_reviews_0438.csv
# Saved 139 reviews to ../data/raw\gojek_reviews_0439.csv
# Saved 137 reviews to ../data/raw\gojek_reviews_0440.csv
# Saved 146 reviews to ../data/raw\gojek_reviews_0441.csv
# Saved 138 reviews to ../data/raw\gojek_reviews_0442.csv
# Saved 124 reviews to ../data/raw\gojek_reviews_0443.csv
# Saved 142 reviews to ../data/raw\gojek_reviews_0444.csv
# Saved 138 reviews to ../data/raw\gojek_reviews_0445.csv
# Saved 136 reviews to ../data/raw\gojek_reviews_0446.csv
# Saved 128 reviews to ../data/raw\gojek_reviews_0447.csv
# Saved 133 reviews to ../data/raw\gojek_reviews_0448.csv
# Saved 147 reviews to ../data/raw\gojek_reviews_0449.csv
# Saved 139 reviews to ../data/raw\gojek_reviews_0450.csv
# Saved 132 reviews to ../data/raw\gojek_reviews_0451.csv
# Saved 149 reviews to ../data/raw\gojek_reviews_0452.csv
# Saved 131 reviews to ../data/raw\gojek_reviews_0453.csv
# Saved 121 reviews to ../data/raw\gojek_reviews_0454.csv
# Saved 138 reviews to ../data/raw\gojek_reviews_0455.csv
# Saved 141 reviews to ../data/raw\gojek_reviews_0456.csv
# Saved 134 reviews to ../data/raw\gojek_reviews_0457.csv
# Saved 149 reviews to ../data/raw\gojek_reviews_0458.csv
# Saved 136 reviews to ../data/raw\gojek_reviews_0459.csv
# Saved 143 reviews to ../data/raw\gojek_reviews_0460.csv
# Saved 137 reviews to ../data/raw\gojek_reviews_0461.csv
# Saved 142 reviews to ../data/raw\gojek_reviews_0462.csv
# Saved 139 reviews to ../data/raw\gojek_reviews_0463.csv
# Saved 129 reviews to ../data/raw\gojek_reviews_0464.csv
# Saved 131 reviews to ../data/raw\gojek_reviews_0465.csv
# Saved 136 reviews to ../data/raw\gojek_reviews_0466.csv
# Saved 155 reviews to ../data/raw\gojek_reviews_0467.csv
# Saved 132 reviews to ../data/raw\gojek_reviews_0468.csv
# Saved 125 reviews to ../data/raw\gojek_reviews_0469.csv
# Saved 136 reviews to ../data/raw\gojek_reviews_0470.csv
# Saved 144 reviews to ../data/raw\gojek_reviews_0471.csv
# Saved 131 reviews to ../data/raw\gojek_reviews_0472.csv
# Saved 135 reviews to ../data/raw\gojek_reviews_0473.csv
# Saved 129 reviews to ../data/raw\gojek_reviews_0474.csv
# Saved 134 reviews to ../data/raw\gojek_reviews_0475.csv
# Saved 150 reviews to ../data/raw\gojek_reviews_0476.csv
# Saved 134 reviews to ../data/raw\gojek_reviews_0477.csv
# Saved 146 reviews to ../data/raw\gojek_reviews_0478.csv
# Saved 141 reviews to ../data/raw\gojek_reviews_0479.csv
# Saved 134 reviews to ../data/raw\gojek_reviews_0480.csv
# Saved 146 reviews to ../data/raw\gojek_reviews_0481.csv
# Saved 143 reviews to ../data/raw\gojek_reviews_0482.csv
# Saved 136 reviews to ../data/raw\gojek_reviews_0483.csv
# Saved 149 reviews to ../data/raw\gojek_reviews_0484.csv
# Saved 141 reviews to ../data/raw\gojek_reviews_0485.csv
# Saved 147 reviews to ../data/raw\gojek_reviews_0486.csv
# Saved 135 reviews to ../data/raw\gojek_reviews_0487.csv
# Saved 148 reviews to ../data/raw\gojek_reviews_0488.csv
# Saved 158 reviews to ../data/raw\gojek_reviews_0489.csv
# Saved 149 reviews to ../data/raw\gojek_reviews_0490.csv
# Saved 146 reviews to ../data/raw\gojek_reviews_0491.csv
# Saved 146 reviews to ../data/raw\gojek_reviews_0492.csv
# Saved 140 reviews to ../data/raw\gojek_reviews_0493.csv
# Saved 139 reviews to ../data/raw\gojek_reviews_0494.csv
# Saved 147 reviews to ../data/raw\gojek_reviews_0495.csv
# Saved 147 reviews to ../data/raw\gojek_reviews_0496.csv
# Saved 142 reviews to ../data/raw\gojek_reviews_0497.csv
# Saved 147 reviews to ../data/raw\gojek_reviews_0498.csv
# Saved 138 reviews to ../data/raw\gojek_reviews_0499.csv
# Saved 140 reviews to ../data/raw\gojek_reviews_0500.csv
# Saved 147 reviews to ../data/raw\gojek_reviews_0501.csv
# Saved 147 reviews to ../data/raw\gojek_reviews_0502.csv
# Saved 134 reviews to ../data/raw\gojek_reviews_0503.csv
# Saved 144 reviews to ../data/raw\gojek_reviews_0504.csv
# Saved 132 reviews to ../data/raw\gojek_reviews_0505.csv
# Saved 139 reviews to ../data/raw\gojek_reviews_0506.csv
# Saved 133 reviews to ../data/raw\gojek_reviews_0507.csv
# Saved 153 reviews to ../data/raw\gojek_reviews_0508.csv
# Saved 147 reviews to ../data/raw\gojek_reviews_0509.csv
# Saved 148 reviews to ../data/raw\gojek_reviews_0510.csv
# Saved 143 reviews to ../data/raw\gojek_reviews_0511.csv
# Saved 135 reviews to ../data/raw\gojek_reviews_0512.csv
# Saved 142 reviews to ../data/raw\gojek_reviews_0513.csv
# Saved 149 reviews to ../data/raw\gojek_reviews_0514.csv
# Saved 132 reviews to ../data/raw\gojek_reviews_0515.csv
# Saved 146 reviews to ../data/raw\gojek_reviews_0516.csv
# Saved 143 reviews to ../data/raw\gojek_reviews_0517.csv
# Saved 150 reviews to ../data/raw\gojek_reviews_0518.csv
# Saved 143 reviews to ../data/raw\gojek_reviews_0519.csv
# Saved 125 reviews to ../data/raw\gojek_reviews_0520.csv
# Saved 145 reviews to ../data/raw\gojek_reviews_0521.csv
# Saved 140 reviews to ../data/raw\gojek_reviews_0522.csv
# Saved 137 reviews to ../data/raw\gojek_reviews_0523.csv
# Saved 144 reviews to ../data/raw\gojek_reviews_0524.csv
# Saved 148 reviews to ../data/raw\gojek_reviews_0525.csv
# Saved 139 reviews to ../data/raw\gojek_reviews_0526.csv
# Saved 142 reviews to ../data/raw\gojek_reviews_0527.csv
# Saved 130 reviews to ../data/raw\gojek_reviews_0528.csv
# Saved 151 reviews to ../data/raw\gojek_reviews_0529.csv
# Saved 147 reviews to ../data/raw\gojek_reviews_0530.csv
# Saved 138 reviews to ../data/raw\gojek_reviews_0531.csv
# Saved 138 reviews to ../data/raw\gojek_reviews_0532.csv
# Saved 126 reviews to ../data/raw\gojek_reviews_0533.csv
# Saved 151 reviews to ../data/raw\gojek_reviews_0534.csv
# Saved 152 reviews to ../data/raw\gojek_reviews_0535.csv
# Saved 153 reviews to ../data/raw\gojek_reviews_0536.csv
# Saved 138 reviews to ../data/raw\gojek_reviews_0537.csv
# Saved 136 reviews to ../data/raw\gojek_reviews_0538.csv
# Saved 144 reviews to ../data/raw\gojek_reviews_0539.csv
# Saved 137 reviews to ../data/raw\gojek_reviews_0540.csv
# Saved 140 reviews to ../data/raw\gojek_reviews_0541.csv
# Saved 145 reviews to ../data/raw\gojek_reviews_0542.csv
# Saved 134 reviews to ../data/raw\gojek_reviews_0543.csv
# Saved 143 reviews to ../data/raw\gojek_reviews_0544.csv
# Saved 132 reviews to ../data/raw\gojek_reviews_0545.csv
# Saved 143 reviews to ../data/raw\gojek_reviews_0546.csv
# Saved 140 reviews to ../data/raw\gojek_reviews_0547.csv
# Saved 147 reviews to ../data/raw\gojek_reviews_0548.csv
# Saved 131 reviews to ../data/raw\gojek_reviews_0549.csv
# Saved 147 reviews to ../data/raw\gojek_reviews_0550.csv
# Saved 128 reviews to ../data/raw\gojek_reviews_0551.csv
# Saved 127 reviews to ../data/raw\gojek_reviews_0552.csv
# Saved 140 reviews to ../data/raw\gojek_reviews_0553.csv
# Saved 138 reviews to ../data/raw\gojek_reviews_0554.csv
# Saved 131 reviews to ../data/raw\gojek_reviews_0555.csv
# Saved 147 reviews to ../data/raw\gojek_reviews_0556.csv
# Saved 140 reviews to ../data/raw\gojek_reviews_0557.csv
# Saved 120 reviews to ../data/raw\gojek_reviews_0558.csv
# Saved 136 reviews to ../data/raw\gojek_reviews_0559.csv
# Saved 133 reviews to ../data/raw\gojek_reviews_0560.csv
# Saved 147 reviews to ../data/raw\gojek_reviews_0561.csv
# Saved 149 reviews to ../data/raw\gojek_reviews_0562.csv
# Saved 138 reviews to ../data/raw\gojek_reviews_0563.csv
# Saved 137 reviews to ../data/raw\gojek_reviews_0564.csv
# Saved 130 reviews to ../data/raw\gojek_reviews_0565.csv
# Saved 145 reviews to ../data/raw\gojek_reviews_0566.csv
# Saved 129 reviews to ../data/raw\gojek_reviews_0567.csv
# Saved 135 reviews to ../data/raw\gojek_reviews_0568.csv
# Saved 133 reviews to ../data/raw\gojek_reviews_0569.csv
# Saved 142 reviews to ../data/raw\gojek_reviews_0570.csv
# Saved 142 reviews to ../data/raw\gojek_reviews_0571.csv
# Saved 142 reviews to ../data/raw\gojek_reviews_0572.csv
# Saved 145 reviews to ../data/raw\gojek_reviews_0573.csv
# Saved 143 reviews to ../data/raw\gojek_reviews_0574.csv
# Saved 133 reviews to ../data/raw\gojek_reviews_0575.csv
# Saved 129 reviews to ../data/raw\gojek_reviews_0576.csv
# Saved 140 reviews to ../data/raw\gojek_reviews_0577.csv
# Saved 140 reviews to ../data/raw\gojek_reviews_0578.csv
# Saved 146 reviews to ../data/raw\gojek_reviews_0579.csv
# Saved 133 reviews to ../data/raw\gojek_reviews_0580.csv
# Saved 138 reviews to ../data/raw\gojek_reviews_0581.csv
# Saved 133 reviews to ../data/raw\gojek_reviews_0582.csv
# Saved 148 reviews to ../data/raw\gojek_reviews_0583.csv
# Saved 139 reviews to ../data/raw\gojek_reviews_0584.csv
# Saved 122 reviews to ../data/raw\gojek_reviews_0585.csv
# Saved 142 reviews to ../data/raw\gojek_reviews_0586.csv
# Saved 131 reviews to ../data/raw\gojek_reviews_0587.csv
# Saved 134 reviews to ../data/raw\gojek_reviews_0588.csv
# Saved 139 reviews to ../data/raw\gojek_reviews_0589.csv
# Saved 142 reviews to ../data/raw\gojek_reviews_0590.csv
# Saved 132 reviews to ../data/raw\gojek_reviews_0591.csv
# Saved 127 reviews to ../data/raw\gojek_reviews_0592.csv
# Saved 144 reviews to ../data/raw\gojek_reviews_0593.csv
# Saved 139 reviews to ../data/raw\gojek_reviews_0594.csv
# Saved 135 reviews to ../data/raw\gojek_reviews_0595.csv
# Saved 135 reviews to ../data/raw\gojek_reviews_0596.csv
# Saved 141 reviews to ../data/raw\gojek_reviews_0597.csv
# Saved 136 reviews to ../data/raw\gojek_reviews_0598.csv
# Saved 148 reviews to ../data/raw\gojek_reviews_0599.csv
# Saved 131 reviews to ../data/raw\gojek_reviews_0600.csv
# Saved 130 reviews to ../data/raw\gojek_reviews_0601.csv
# Saved 139 reviews to ../data/raw\gojek_reviews_0602.csv
# Saved 136 reviews to ../data/raw\gojek_reviews_0603.csv
# Saved 131 reviews to ../data/raw\gojek_reviews_0604.csv
# Saved 143 reviews to ../data/raw\gojek_reviews_0605.csv
# Saved 142 reviews to ../data/raw\gojek_reviews_0606.csv
# Saved 138 reviews to ../data/raw\gojek_reviews_0607.csv
# Saved 131 reviews to ../data/raw\gojek_reviews_0608.csv
# Saved 142 reviews to ../data/raw\gojek_reviews_0609.csv
# Saved 126 reviews to ../data/raw\gojek_reviews_0610.csv
# Saved 131 reviews to ../data/raw\gojek_reviews_0611.csv
# Saved 139 reviews to ../data/raw\gojek_reviews_0612.csv
# Saved 150 reviews to ../data/raw\gojek_reviews_0613.csv
# Saved 136 reviews to ../data/raw\gojek_reviews_0614.csv
# Saved 147 reviews to ../data/raw\gojek_reviews_0615.csv
# Saved 154 reviews to ../data/raw\gojek_reviews_0616.csv
# Saved 145 reviews to ../data/raw\gojek_reviews_0617.csv
# Saved 138 reviews to ../data/raw\gojek_reviews_0618.csv
# Saved 141 reviews to ../data/raw\gojek_reviews_0619.csv
# Saved 131 reviews to ../data/raw\gojek_reviews_0620.csv
# Saved 120 reviews to ../data/raw\gojek_reviews_0621.csv
# Saved 141 reviews to ../data/raw\gojek_reviews_0622.csv
# Saved 130 reviews to ../data/raw\gojek_reviews_0623.csv
# Saved 138 reviews to ../data/raw\gojek_reviews_0624.csv
# Saved 133 reviews to ../data/raw\gojek_reviews_0625.csv
# Saved 146 reviews to ../data/raw\gojek_reviews_0626.csv
# Saved 141 reviews to ../data/raw\gojek_reviews_0627.csv
# Saved 129 reviews to ../data/raw\gojek_reviews_0628.csv
# Saved 138 reviews to ../data/raw\gojek_reviews_0629.csv
# Saved 149 reviews to ../data/raw\gojek_reviews_0630.csv
# Saved 139 reviews to ../data/raw\gojek_reviews_0631.csv
# Saved 143 reviews to ../data/raw\gojek_reviews_0632.csv
# Saved 137 reviews to ../data/raw\gojek_reviews_0633.csv
# Saved 142 reviews to ../data/raw\gojek_reviews_0634.csv
# Saved 146 reviews to ../data/raw\gojek_reviews_0635.csv
# Saved 148 reviews to ../data/raw\gojek_reviews_0636.csv
# Saved 135 reviews to ../data/raw\gojek_reviews_0637.csv
# Saved 143 reviews to ../data/raw\gojek_reviews_0638.csv
# Saved 137 reviews to ../data/raw\gojek_reviews_0639.csv
# Saved 138 reviews to ../data/raw\gojek_reviews_0640.csv
# Saved 135 reviews to ../data/raw\gojek_reviews_0641.csv
# Saved 151 reviews to ../data/raw\gojek_reviews_0642.csv
# Saved 145 reviews to ../data/raw\gojek_reviews_0643.csv
# Saved 145 reviews to ../data/raw\gojek_reviews_0644.csv
# Saved 140 reviews to ../data/raw\gojek_reviews_0645.csv
# Saved 135 reviews to ../data/raw\gojek_reviews_0646.csv
# Saved 138 reviews to ../data/raw\gojek_reviews_0647.csv
# Saved 141 reviews to ../data/raw\gojek_reviews_0648.csv
# Saved 132 reviews to ../data/raw\gojek_reviews_0649.csv
# Saved 141 reviews to ../data/raw\gojek_reviews_0650.csv
# Saved 147 reviews to ../data/raw\gojek_reviews_0651.csv
# Saved 130 reviews to ../data/raw\gojek_reviews_0652.csv
# Saved 149 reviews to ../data/raw\gojek_reviews_0653.csv
# Saved 143 reviews to ../data/raw\gojek_reviews_0654.csv
# Saved 142 reviews to ../data/raw\gojek_reviews_0655.csv
# Saved 135 reviews to ../data/raw\gojek_reviews_0656.csv
# Saved 125 reviews to ../data/raw\gojek_reviews_0657.csv
# Saved 142 reviews to ../data/raw\gojek_reviews_0658.csv
# Saved 137 reviews to ../data/raw\gojek_reviews_0659.csv
# Saved 149 reviews to ../data/raw\gojek_reviews_0660.csv
# Saved 142 reviews to ../data/raw\gojek_reviews_0661.csv
# Saved 148 reviews to ../data/raw\gojek_reviews_0662.csv
# Saved 137 reviews to ../data/raw\gojek_reviews_0663.csv
# Saved 142 reviews to ../data/raw\gojek_reviews_0664.csv
# Saved 138 reviews to ../data/raw\gojek_reviews_0665.csv
# Saved 142 reviews to ../data/raw\gojek_reviews_0666.csv
# Saved 144 reviews to ../data/raw\gojek_reviews_0667.csv
# Saved 141 reviews to ../data/raw\gojek_reviews_0668.csv
# Saved 139 reviews to ../data/raw\gojek_reviews_0669.csv
# Saved 129 reviews to ../data/raw\gojek_reviews_0670.csv
# Saved 138 reviews to ../data/raw\gojek_reviews_0671.csv
# Saved 137 reviews to ../data/raw\gojek_reviews_0672.csv
# Saved 140 reviews to ../data/raw\gojek_reviews_0673.csv
# Saved 142 reviews to ../data/raw\gojek_reviews_0674.csv
# Saved 136 reviews to ../data/raw\gojek_reviews_0675.csv
# Saved 140 reviews to ../data/raw\gojek_reviews_0676.csv
# Saved 146 reviews to ../data/raw\gojek_reviews_0677.csv
# Saved 141 reviews to ../data/raw\gojek_reviews_0678.csv
# Saved 138 reviews to ../data/raw\gojek_reviews_0679.csv
# Saved 140 reviews to ../data/raw\gojek_reviews_0680.csv
# Saved 142 reviews to ../data/raw\gojek_reviews_0681.csv
# Saved 140 reviews to ../data/raw\gojek_reviews_0682.csv
# Saved 156 reviews to ../data/raw\gojek_reviews_0683.csv
# Saved 141 reviews to ../data/raw\gojek_reviews_0684.csv
# Saved 153 reviews to ../data/raw\gojek_reviews_0685.csv
# Saved 147 reviews to ../data/raw\gojek_reviews_0686.csv
# Saved 140 reviews to ../data/raw\gojek_reviews_0687.csv
# Saved 137 reviews to ../data/raw\gojek_reviews_0688.csv
# Saved 135 reviews to ../data/raw\gojek_reviews_0689.csv
# Saved 146 reviews to ../data/raw\gojek_reviews_0690.csv
# Saved 134 reviews to ../data/raw\gojek_reviews_0691.csv
# Saved 143 reviews to ../data/raw\gojek_reviews_0692.csv
# Saved 131 reviews to ../data/raw\gojek_reviews_0693.csv
# Saved 126 reviews to ../data/raw\gojek_reviews_0694.csv
# Saved 134 reviews to ../data/raw\gojek_reviews_0695.csv
# Saved 144 reviews to ../data/raw\gojek_reviews_0696.csv
# Saved 144 reviews to ../data/raw\gojek_reviews_0697.csv
# Saved 133 reviews to ../data/raw\gojek_reviews_0698.csv
# Saved 154 reviews to ../data/raw\gojek_reviews_0699.csv
# Saved 131 reviews to ../data/raw\gojek_reviews_0700.csv
# Saved 137 reviews to ../data/raw\gojek_reviews_0701.csv
# Saved 139 reviews to ../data/raw\gojek_reviews_0702.csv
# Saved 150 reviews to ../data/raw\gojek_reviews_0703.csv
# Saved 135 reviews to ../data/raw\gojek_reviews_0704.csv
# Saved 139 reviews to ../data/raw\gojek_reviews_0705.csv
# Saved 143 reviews to ../data/raw\gojek_reviews_0706.csv
# Saved 149 reviews to ../data/raw\gojek_reviews_0707.csv
# Saved 139 reviews to ../data/raw\gojek_reviews_0708.csv
# Saved 129 reviews to ../data/raw\gojek_reviews_0709.csv
# Saved 133 reviews to ../data/raw\gojek_reviews_0710.csv
# Saved 147 reviews to ../data/raw\gojek_reviews_0711.csv
# Saved 146 reviews to ../data/raw\gojek_reviews_0712.csv
# Saved 139 reviews to ../data/raw\gojek_reviews_0713.csv
# Saved 150 reviews to ../data/raw\gojek_reviews_0714.csv
# Saved 151 reviews to ../data/raw\gojek_reviews_0715.csv
# Saved 149 reviews to ../data/raw\gojek_reviews_0716.csv
# Saved 137 reviews to ../data/raw\gojek_reviews_0717.csv
# Saved 134 reviews to ../data/raw\gojek_reviews_0718.csv
# Saved 140 reviews to ../data/raw\gojek_reviews_0719.csv
# Saved 142 reviews to ../data/raw\gojek_reviews_0720.csv
# Saved 146 reviews to ../data/raw\gojek_reviews_0721.csv
# Saved 136 reviews to ../data/raw\gojek_reviews_0722.csv
# Saved 147 reviews to ../data/raw\gojek_reviews_0723.csv
# Saved 146 reviews to ../data/raw\gojek_reviews_0724.csv
# Saved 140 reviews to ../data/raw\gojek_reviews_0725.csv
# Saved 137 reviews to ../data/raw\gojek_reviews_0726.csv
# Saved 144 reviews to ../data/raw\gojek_reviews_0727.csv
# Scraping completed. Total reviews scraped: 100127

# %%
import os
import pandas as pd

OUTPUT_DIR = "../data/raw"
BATCH_PREFIX = "gojek_reviews_"

def batch_merge(output_fname="../data/gojek_reviews_full.csv"):
    all_files = sorted([
        os.path.join(OUTPUT_DIR, f)
        for f in os.listdir(OUTPUT_DIR)
        if f.startswith(BATCH_PREFIX) and f.endswith(".csv")
    ])

    if not all_files:
        print("No batch files found to merge.")
        return None

    df_list = []
    for f in all_files:
        try:
            df = pd.read_csv(f, dtype=str)
            df_list.append(df)
            print(f"Loaded {os.path.basename(f)} ({len(df)} rows)")
        except Exception as e:
            print(f"Error reading {f}: {e}")

    if not df_list:
        print("No valid dataframes to merge.")
        return None

    full_df = pd.concat(df_list, ignore_index=True)
    full_df.drop_duplicates(subset=["reviewId"], inplace=True)
    full_df = full_df[full_df["content"].notna() & (full_df["content"].str.strip() != "")]

    if "score" in full_df.columns:
        full_df["score"] = full_df["score"].astype(int)

    # Pastikan folder output-nya ada
    os.makedirs(os.path.dirname(output_fname), exist_ok=True)
    full_df.to_csv(output_fname, index=False, encoding="utf-8-sig")

    print(f"\nMerged {len(all_files)} batches → {output_fname}")
    print(f"Total unique reviews: {len(full_df):,}")
    return full_df


# Jalankan
merged_df = batch_merge()
# Out:
# Loaded gojek_reviews_0000.csv (132 rows)
# Loaded gojek_reviews_0001.csv (139 rows)
# Loaded gojek_reviews_0002.csv (147 rows)
# Loaded gojek_reviews_0003.csv (137 rows)
# Loaded gojek_reviews_0004.csv (136 rows)
# Loaded gojek_reviews_0005.csv (155 rows)
# Loaded gojek_reviews_0006.csv (136 rows)
# Loaded gojek_reviews_0007.csv (141 rows)
# Loaded gojek_reviews_0008.csv (142 rows)
# Loaded gojek_reviews_0009.csv (125 rows)
# Loaded gojek_reviews_0010.csv (129 rows)
# Loaded gojek_reviews_0011.csv (132 rows)
# Loaded gojek_reviews_0012.csv (121 rows)
# Loaded gojek_reviews_0013.csv (141 rows)
# Loaded gojek_reviews_0014.csv (150 rows)
# Loaded gojek_reviews_0015.csv (141 rows)
# Loaded gojek_reviews_0016.csv (122 rows)
# Loaded gojek_reviews_0017.csv (149 rows)
# Loaded gojek_reviews_0018.csv (133 rows)
# Loaded gojek_reviews_0019.csv (135 rows)
# Loaded gojek_reviews_0020.csv (131 rows)
# Loaded gojek_reviews_0021.csv (126 rows)
# Loaded gojek_reviews_0022.csv (125 rows)
# Loaded gojek_reviews_0023.csv (129 rows)
# Loaded gojek_reviews_0024.csv (131 rows)
# Loaded gojek_reviews_0025.csv (137 rows)
# Loaded gojek_reviews_0026.csv (130 rows)
# Loaded gojek_reviews_0027.csv (132 rows)
# Loaded gojek_reviews_0028.csv (135 rows)
# Loaded gojek_reviews_0029.csv (132 rows)
# Loaded gojek_reviews_0030.csv (123 rows)
# Loaded gojek_reviews_0031.csv (133 rows)
# Loaded gojek_reviews_0032.csv (124 rows)
# Loaded gojek_reviews_0033.csv (123 rows)
# Loaded gojek_reviews_0034.csv (122 rows)
# Loaded gojek_reviews_0035.csv (132 rows)
# Loaded gojek_reviews_0036.csv (135 rows)
# Loaded gojek_reviews_0037.csv (121 rows)
# Loaded gojek_reviews_0038.csv (137 rows)
# Loaded gojek_reviews_0039.csv (132 rows)
# Loaded gojek_reviews_0040.csv (122 rows)
# Loaded gojek_reviews_0041.csv (142 rows)
# Loaded gojek_reviews_0042.csv (126 rows)
# Loaded gojek_reviews_0043.csv (135 rows)
# Loaded gojek_reviews_0044.csv (143 rows)
# Loaded gojek_reviews_0045.csv (138 rows)
# Loaded gojek_reviews_0046.csv (138 rows)
# Loaded gojek_reviews_0047.csv (131 rows)
# Loaded gojek_reviews_0048.csv (131 rows)
# Loaded gojek_reviews_0049.csv (141 rows)
# Loaded gojek_reviews_0050.csv (136 rows)
# Loaded gojek_reviews_0051.csv (167 rows)
# Loaded gojek_reviews_0052.csv (145 rows)
# Loaded gojek_reviews_0053.csv (129 rows)
# Loaded gojek_reviews_0054.csv (139 rows)
# Loaded gojek_reviews_0055.csv (137 rows)
# Loaded gojek_reviews_0056.csv (144 rows)
# Loaded gojek_reviews_0057.csv (130 rows)
# Loaded gojek_reviews_0058.csv (134 rows)
# Loaded gojek_reviews_0059.csv (131 rows)
# Loaded gojek_reviews_0060.csv (144 rows)
# Loaded gojek_reviews_0061.csv (129 rows)
# Loaded gojek_reviews_0062.csv (127 rows)
# Loaded gojek_reviews_0063.csv (134 rows)
# Loaded gojek_reviews_0064.csv (133 rows)
# Loaded gojek_reviews_0065.csv (141 rows)
# Loaded gojek_reviews_0066.csv (126 rows)
# Loaded gojek_reviews_0067.csv (133 rows)
# Loaded gojek_reviews_0068.csv (118 rows)
# Loaded gojek_reviews_0069.csv (135 rows)
# Loaded gojek_reviews_0070.csv (113 rows)
# Loaded gojek_reviews_0071.csv (128 rows)
# Loaded gojek_reviews_0072.csv (143 rows)
# Loaded gojek_reviews_0073.csv (124 rows)
# Loaded gojek_reviews_0074.csv (135 rows)
# Loaded gojek_reviews_0075.csv (136 rows)
# Loaded gojek_reviews_0076.csv (131 rows)
# Loaded gojek_reviews_0077.csv (132 rows)
# Loaded gojek_reviews_0078.csv (136 rows)
# Loaded gojek_reviews_0079.csv (137 rows)
# Loaded gojek_reviews_0080.csv (132 rows)
# Loaded gojek_reviews_0081.csv (130 rows)
# Loaded gojek_reviews_0082.csv (138 rows)
# Loaded gojek_reviews_0083.csv (120 rows)
# Loaded gojek_reviews_0084.csv (129 rows)
# Loaded gojek_reviews_0085.csv (122 rows)
# Loaded gojek_reviews_0086.csv (128 rows)
# Loaded gojek_reviews_0087.csv (117 rows)
# Loaded gojek_reviews_0088.csv (124 rows)
# Loaded gojek_reviews_0089.csv (140 rows)
# Loaded gojek_reviews_0090.csv (129 rows)
# Loaded gojek_reviews_0091.csv (121 rows)
# Loaded gojek_reviews_0092.csv (118 rows)
# Loaded gojek_reviews_0093.csv (136 rows)
# Loaded gojek_reviews_0094.csv (131 rows)
# Loaded gojek_reviews_0095.csv (135 rows)
# Loaded gojek_reviews_0096.csv (133 rows)
# Loaded gojek_reviews_0097.csv (128 rows)
# Loaded gojek_reviews_0098.csv (118 rows)
# Loaded gojek_reviews_0099.csv (134 rows)
# Loaded gojek_reviews_0100.csv (125 rows)
# Loaded gojek_reviews_0101.csv (128 rows)
# Loaded gojek_reviews_0102.csv (132 rows)
# Loaded gojek_reviews_0103.csv (134 rows)
# Loaded gojek_reviews_0104.csv (118 rows)
# Loaded gojek_reviews_0105.csv (133 rows)
# Loaded gojek_reviews_0106.csv (128 rows)
# Loaded gojek_reviews_0107.csv (130 rows)
# Loaded gojek_reviews_0108.csv (133 rows)
# Loaded gojek_reviews_0109.csv (128 rows)
# Loaded gojek_reviews_0110.csv (121 rows)
# Loaded gojek_reviews_0111.csv (129 rows)
# Loaded gojek_reviews_0112.csv (122 rows)
# Loaded gojek_reviews_0113.csv (118 rows)
# Loaded gojek_reviews_0114.csv (131 rows)
# Loaded gojek_reviews_0115.csv (142 rows)
# Loaded gojek_reviews_0116.csv (115 rows)
# Loaded gojek_reviews_0117.csv (121 rows)
# Loaded gojek_reviews_0118.csv (142 rows)
# Loaded gojek_reviews_0119.csv (123 rows)
# Loaded gojek_reviews_0120.csv (133 rows)
# Loaded gojek_reviews_0121.csv (128 rows)
# Loaded gojek_reviews_0122.csv (121 rows)
# Loaded gojek_reviews_0123.csv (115 rows)
# Loaded gojek_reviews_0124.csv (126 rows)
# Loaded gojek_reviews_0125.csv (133 rows)
# Loaded gojek_reviews_0126.csv (117 rows)
# Loaded gojek_reviews_0127.csv (132 rows)
# Loaded gojek_reviews_0128.csv (132 rows)
# Loaded gojek_reviews_0129.csv (136 rows)
# Loaded gojek_reviews_0130.csv (128 rows)
# Loaded gojek_reviews_0131.csv (128 rows)
# Loaded gojek_reviews_0132.csv (120 rows)
# Loaded gojek_reviews_0133.csv (128 rows)
# Loaded gojek_reviews_0134.csv (132 rows)
# Loaded gojek_reviews_0135.csv (128 rows)
# Loaded gojek_reviews_0136.csv (131 rows)
# Loaded gojek_reviews_0137.csv (145 rows)
# Loaded gojek_reviews_0138.csv (145 rows)
# Loaded gojek_reviews_0139.csv (127 rows)
# Loaded gojek_reviews_0140.csv (115 rows)
# Loaded gojek_reviews_0141.csv (137 rows)
# Loaded gojek_reviews_0142.csv (134 rows)
# Loaded gojek_reviews_0143.csv (132 rows)
# Loaded gojek_reviews_0144.csv (139 rows)
# Loaded gojek_reviews_0145.csv (130 rows)
# Loaded gojek_reviews_0146.csv (123 rows)
# Loaded gojek_reviews_0147.csv (138 rows)
# Loaded gojek_reviews_0148.csv (141 rows)
# Loaded gojek_reviews_0149.csv (137 rows)
# Loaded gojek_reviews_0150.csv (136 rows)
# Loaded gojek_reviews_0151.csv (160 rows)
# Loaded gojek_reviews_0152.csv (141 rows)
# Loaded gojek_reviews_0153.csv (135 rows)
# Loaded gojek_reviews_0154.csv (130 rows)
# Loaded gojek_reviews_0155.csv (161 rows)
# Loaded gojek_reviews_0156.csv (153 rows)
# Loaded gojek_reviews_0157.csv (151 rows)
# Loaded gojek_reviews_0158.csv (140 rows)
# Loaded gojek_reviews_0159.csv (145 rows)
# Loaded gojek_reviews_0160.csv (143 rows)
# Loaded gojek_reviews_0161.csv (132 rows)
# Loaded gojek_reviews_0162.csv (133 rows)
# Loaded gojek_reviews_0163.csv (122 rows)
# Loaded gojek_reviews_0164.csv (131 rows)
# Loaded gojek_reviews_0165.csv (143 rows)
# Loaded gojek_reviews_0166.csv (137 rows)
# Loaded gojek_reviews_0167.csv (131 rows)
# Loaded gojek_reviews_0168.csv (142 rows)
# Loaded gojek_reviews_0169.csv (134 rows)
# Loaded gojek_reviews_0170.csv (135 rows)
# Loaded gojek_reviews_0171.csv (137 rows)
# Loaded gojek_reviews_0172.csv (118 rows)
# Loaded gojek_reviews_0173.csv (145 rows)
# Loaded gojek_reviews_0174.csv (130 rows)
# Loaded gojek_reviews_0175.csv (141 rows)
# Loaded gojek_reviews_0176.csv (135 rows)
# Loaded gojek_reviews_0177.csv (140 rows)
# Loaded gojek_reviews_0178.csv (136 rows)
# Loaded gojek_reviews_0179.csv (138 rows)
# Loaded gojek_reviews_0180.csv (140 rows)
# Loaded gojek_reviews_0181.csv (152 rows)
# Loaded gojek_reviews_0182.csv (132 rows)
# Loaded gojek_reviews_0183.csv (142 rows)
# Loaded gojek_reviews_0184.csv (135 rows)
# Loaded gojek_reviews_0185.csv (149 rows)
# Loaded gojek_reviews_0186.csv (167 rows)
# Loaded gojek_reviews_0187.csv (152 rows)
# Loaded gojek_reviews_0188.csv (143 rows)
# Loaded gojek_reviews_0189.csv (137 rows)
# Loaded gojek_reviews_0190.csv (142 rows)
# Loaded gojek_reviews_0191.csv (139 rows)
# Loaded gojek_reviews_0192.csv (140 rows)
# Loaded gojek_reviews_0193.csv (134 rows)
# Loaded gojek_reviews_0194.csv (138 rows)
# Loaded gojek_reviews_0195.csv (135 rows)
# Loaded gojek_reviews_0196.csv (137 rows)
# Loaded gojek_reviews_0197.csv (136 rows)
# Loaded gojek_reviews_0198.csv (146 rows)
# Loaded gojek_reviews_0199.csv (141 rows)
# Loaded gojek_reviews_0200.csv (135 rows)
# Loaded gojek_reviews_0201.csv (143 rows)
# Loaded gojek_reviews_0202.csv (133 rows)
# Loaded gojek_reviews_0203.csv (153 rows)
# Loaded gojek_reviews_0204.csv (143 rows)
# Loaded gojek_reviews_0205.csv (141 rows)
# Loaded gojek_reviews_0206.csv (140 rows)
# Loaded gojek_reviews_0207.csv (135 rows)
# Loaded gojek_reviews_0208.csv (138 rows)
# Loaded gojek_reviews_0209.csv (141 rows)
# Loaded gojek_reviews_0210.csv (151 rows)
# Loaded gojek_reviews_0211.csv (141 rows)
# Loaded gojek_reviews_0212.csv (146 rows)
# Loaded gojek_reviews_0213.csv (134 rows)
# Loaded gojek_reviews_0214.csv (142 rows)
# Loaded gojek_reviews_0215.csv (139 rows)
# Loaded gojek_reviews_0216.csv (147 rows)
# Loaded gojek_reviews_0217.csv (145 rows)
# Loaded gojek_reviews_0218.csv (140 rows)
# Loaded gojek_reviews_0219.csv (139 rows)
# Loaded gojek_reviews_0220.csv (135 rows)
# Loaded gojek_reviews_0221.csv (148 rows)
# Loaded gojek_reviews_0222.csv (139 rows)
# Loaded gojek_reviews_0223.csv (137 rows)
# Loaded gojek_reviews_0224.csv (145 rows)
# Loaded gojek_reviews_0225.csv (133 rows)
# Loaded gojek_reviews_0226.csv (164 rows)
# Loaded gojek_reviews_0227.csv (151 rows)
# Loaded gojek_reviews_0228.csv (136 rows)
# Loaded gojek_reviews_0229.csv (139 rows)
# Loaded gojek_reviews_0230.csv (133 rows)
# Loaded gojek_reviews_0231.csv (132 rows)
# Loaded gojek_reviews_0232.csv (138 rows)
# Loaded gojek_reviews_0233.csv (134 rows)
# Loaded gojek_reviews_0234.csv (150 rows)
# Loaded gojek_reviews_0235.csv (145 rows)
# Loaded gojek_reviews_0236.csv (146 rows)
# Loaded gojek_reviews_0237.csv (134 rows)
# Loaded gojek_reviews_0238.csv (143 rows)
# Loaded gojek_reviews_0239.csv (132 rows)
# Loaded gojek_reviews_0240.csv (125 rows)
# Loaded gojek_reviews_0241.csv (140 rows)
# Loaded gojek_reviews_0242.csv (137 rows)
# Loaded gojek_reviews_0243.csv (138 rows)
# Loaded gojek_reviews_0244.csv (146 rows)
# Loaded gojek_reviews_0245.csv (140 rows)
# Loaded gojek_reviews_0246.csv (148 rows)
# Loaded gojek_reviews_0247.csv (125 rows)
# Loaded gojek_reviews_0248.csv (139 rows)
# Loaded gojek_reviews_0249.csv (146 rows)
# Loaded gojek_reviews_0250.csv (150 rows)
# Loaded gojek_reviews_0251.csv (144 rows)
# Loaded gojek_reviews_0252.csv (154 rows)
# Loaded gojek_reviews_0253.csv (147 rows)
# Loaded gojek_reviews_0254.csv (143 rows)
# Loaded gojek_reviews_0255.csv (144 rows)
# Loaded gojek_reviews_0256.csv (153 rows)
# Loaded gojek_reviews_0257.csv (142 rows)
# Loaded gojek_reviews_0258.csv (149 rows)
# Loaded gojek_reviews_0259.csv (150 rows)
# Loaded gojek_reviews_0260.csv (137 rows)
# Loaded gojek_reviews_0261.csv (139 rows)
# Loaded gojek_reviews_0262.csv (128 rows)
# Loaded gojek_reviews_0263.csv (158 rows)
# Loaded gojek_reviews_0264.csv (148 rows)
# Loaded gojek_reviews_0265.csv (138 rows)
# Loaded gojek_reviews_0266.csv (137 rows)
# Loaded gojek_reviews_0267.csv (140 rows)
# Loaded gojek_reviews_0268.csv (144 rows)
# Loaded gojek_reviews_0269.csv (147 rows)
# Loaded gojek_reviews_0270.csv (142 rows)
# Loaded gojek_reviews_0271.csv (139 rows)
# Loaded gojek_reviews_0272.csv (153 rows)
# Loaded gojek_reviews_0273.csv (141 rows)
# Loaded gojek_reviews_0274.csv (143 rows)
# Loaded gojek_reviews_0275.csv (137 rows)
# Loaded gojek_reviews_0276.csv (136 rows)
# Loaded gojek_reviews_0277.csv (133 rows)
# Loaded gojek_reviews_0278.csv (141 rows)
# Loaded gojek_reviews_0279.csv (141 rows)
# Loaded gojek_reviews_0280.csv (156 rows)
# Loaded gojek_reviews_0281.csv (140 rows)
# Loaded gojek_reviews_0282.csv (158 rows)
# Loaded gojek_reviews_0283.csv (141 rows)
# Loaded gojek_reviews_0284.csv (145 rows)
# Loaded gojek_reviews_0285.csv (145 rows)
# Loaded gojek_reviews_0286.csv (131 rows)
# Loaded gojek_reviews_0287.csv (145 rows)
# Loaded gojek_reviews_0288.csv (144 rows)
# Loaded gojek_reviews_0289.csv (138 rows)
# Loaded gojek_reviews_0290.csv (146 rows)
# Loaded gojek_reviews_0291.csv (139 rows)
# Loaded gojek_reviews_0292.csv (134 rows)
# Loaded gojek_reviews_0293.csv (136 rows)
# Loaded gojek_reviews_0294.csv (143 rows)
# Loaded gojek_reviews_0295.csv (137 rows)
# Loaded gojek_reviews_0296.csv (139 rows)
# Loaded gojek_reviews_0297.csv (133 rows)
# Loaded gojek_reviews_0298.csv (136 rows)
# Loaded gojek_reviews_0299.csv (150 rows)
# Loaded gojek_reviews_0300.csv (133 rows)
# Loaded gojek_reviews_0301.csv (135 rows)
# Loaded gojek_reviews_0302.csv (141 rows)
# Loaded gojek_reviews_0303.csv (151 rows)
# Loaded gojek_reviews_0304.csv (133 rows)
# Loaded gojek_reviews_0305.csv (143 rows)
# Loaded gojek_reviews_0306.csv (138 rows)
# Loaded gojek_reviews_0307.csv (152 rows)
# Loaded gojek_reviews_0308.csv (145 rows)
# Loaded gojek_reviews_0309.csv (142 rows)
# Loaded gojek_reviews_0310.csv (148 rows)
# Loaded gojek_reviews_0311.csv (141 rows)
# Loaded gojek_reviews_0312.csv (147 rows)
# Loaded gojek_reviews_0313.csv (147 rows)
# Loaded gojek_reviews_0314.csv (130 rows)
# Loaded gojek_reviews_0315.csv (133 rows)
# Loaded gojek_reviews_0316.csv (152 rows)
# Loaded gojek_reviews_0317.csv (142 rows)
# Loaded gojek_reviews_0318.csv (140 rows)
# Loaded gojek_reviews_0319.csv (142 rows)
# Loaded gojek_reviews_0320.csv (147 rows)
# Loaded gojek_reviews_0321.csv (146 rows)
# Loaded gojek_reviews_0322.csv (143 rows)
# Loaded gojek_reviews_0323.csv (131 rows)
# Loaded gojek_reviews_0324.csv (138 rows)
# Loaded gojek_reviews_0325.csv (142 rows)
# Loaded gojek_reviews_0326.csv (143 rows)
# Loaded gojek_reviews_0327.csv (138 rows)
# Loaded gojek_reviews_0328.csv (139 rows)
# Loaded gojek_reviews_0329.csv (133 rows)
# Loaded gojek_reviews_0330.csv (149 rows)
# Loaded gojek_reviews_0331.csv (131 rows)
# Loaded gojek_reviews_0332.csv (141 rows)
# Loaded gojek_reviews_0333.csv (140 rows)
# Loaded gojek_reviews_0334.csv (131 rows)
# Loaded gojek_reviews_0335.csv (124 rows)
# Loaded gojek_reviews_0336.csv (127 rows)
# Loaded gojek_reviews_0337.csv (144 rows)
# Loaded gojek_reviews_0338.csv (128 rows)
# Loaded gojek_reviews_0339.csv (141 rows)
# Loaded gojek_reviews_0340.csv (143 rows)
# Loaded gojek_reviews_0341.csv (137 rows)
# Loaded gojek_reviews_0342.csv (134 rows)
# Loaded gojek_reviews_0343.csv (137 rows)
# Loaded gojek_reviews_0344.csv (135 rows)
# Loaded gojek_reviews_0345.csv (140 rows)
# Loaded gojek_reviews_0346.csv (139 rows)
# Loaded gojek_reviews_0347.csv (129 rows)
# Loaded gojek_reviews_0348.csv (137 rows)
# Loaded gojek_reviews_0349.csv (128 rows)
# Loaded gojek_reviews_0350.csv (136 rows)
# Loaded gojek_reviews_0351.csv (124 rows)
# Loaded gojek_reviews_0352.csv (140 rows)
# Loaded gojek_reviews_0353.csv (138 rows)
# Loaded gojek_reviews_0354.csv (136 rows)
# Loaded gojek_reviews_0355.csv (148 rows)
# Loaded gojek_reviews_0356.csv (129 rows)
# Loaded gojek_reviews_0357.csv (136 rows)
# Loaded gojek_reviews_0358.csv (133 rows)
# Loaded gojek_reviews_0359.csv (120 rows)
# Loaded gojek_reviews_0360.csv (136 rows)
# Loaded gojek_reviews_0361.csv (119 rows)
# Loaded gojek_reviews_0362.csv (132 rows)
# Loaded gojek_reviews_0363.csv (141 rows)
# Loaded gojek_reviews_0364.csv (126 rows)
# Loaded gojek_reviews_0365.csv (144 rows)
# Loaded gojek_reviews_0366.csv (145 rows)
# Loaded gojek_reviews_0367.csv (135 rows)
# Loaded gojek_reviews_0368.csv (122 rows)
# Loaded gojek_reviews_0369.csv (134 rows)
# Loaded gojek_reviews_0370.csv (126 rows)
# Loaded gojek_reviews_0371.csv (138 rows)
# Loaded gojek_reviews_0372.csv (124 rows)
# Loaded gojek_reviews_0373.csv (131 rows)
# Loaded gojek_reviews_0374.csv (123 rows)
# Loaded gojek_reviews_0375.csv (140 rows)
# Loaded gojek_reviews_0376.csv (143 rows)
# Loaded gojek_reviews_0377.csv (137 rows)
# Loaded gojek_reviews_0378.csv (136 rows)
# Loaded gojek_reviews_0379.csv (137 rows)
# Loaded gojek_reviews_0380.csv (135 rows)
# Loaded gojek_reviews_0381.csv (128 rows)
# Loaded gojek_reviews_0382.csv (139 rows)
# Loaded gojek_reviews_0383.csv (134 rows)
# Loaded gojek_reviews_0384.csv (126 rows)
# Loaded gojek_reviews_0385.csv (133 rows)
# Loaded gojek_reviews_0386.csv (134 rows)
# Loaded gojek_reviews_0387.csv (123 rows)
# Loaded gojek_reviews_0388.csv (131 rows)
# Loaded gojek_reviews_0389.csv (128 rows)
# Loaded gojek_reviews_0390.csv (144 rows)
# Loaded gojek_reviews_0391.csv (123 rows)
# Loaded gojek_reviews_0392.csv (121 rows)
# Loaded gojek_reviews_0393.csv (139 rows)
# Loaded gojek_reviews_0394.csv (131 rows)
# Loaded gojek_reviews_0395.csv (141 rows)
# Loaded gojek_reviews_0396.csv (146 rows)
# Loaded gojek_reviews_0397.csv (134 rows)
# Loaded gojek_reviews_0398.csv (139 rows)
# Loaded gojek_reviews_0399.csv (144 rows)
# Loaded gojek_reviews_0400.csv (136 rows)
# Loaded gojek_reviews_0401.csv (140 rows)
# Loaded gojek_reviews_0402.csv (126 rows)
# Loaded gojek_reviews_0403.csv (140 rows)
# Loaded gojek_reviews_0404.csv (137 rows)
# Loaded gojek_reviews_0405.csv (133 rows)
# Loaded gojek_reviews_0406.csv (120 rows)
# Loaded gojek_reviews_0407.csv (135 rows)
# Loaded gojek_reviews_0408.csv (135 rows)
# Loaded gojek_reviews_0409.csv (132 rows)
# Loaded gojek_reviews_0410.csv (136 rows)
# Loaded gojek_reviews_0411.csv (123 rows)
# Loaded gojek_reviews_0412.csv (132 rows)
# Loaded gojek_reviews_0413.csv (146 rows)
# Loaded gojek_reviews_0414.csv (145 rows)
# Loaded gojek_reviews_0415.csv (131 rows)
# Loaded gojek_reviews_0416.csv (135 rows)
# Loaded gojek_reviews_0417.csv (150 rows)
# Loaded gojek_reviews_0418.csv (129 rows)
# Loaded gojek_reviews_0419.csv (142 rows)
# Loaded gojek_reviews_0420.csv (132 rows)
# Loaded gojek_reviews_0421.csv (133 rows)
# Loaded gojek_reviews_0422.csv (136 rows)
# Loaded gojek_reviews_0423.csv (142 rows)
# Loaded gojek_reviews_0424.csv (142 rows)
# Loaded gojek_reviews_0425.csv (138 rows)
# Loaded gojek_reviews_0426.csv (145 rows)
# Loaded gojek_reviews_0427.csv (127 rows)
# Loaded gojek_reviews_0428.csv (132 rows)
# Loaded gojek_reviews_0429.csv (137 rows)
# Loaded gojek_reviews_0430.csv (137 rows)
# Loaded gojek_reviews_0431.csv (129 rows)
# Loaded gojek_reviews_0432.csv (135 rows)
# Loaded gojek_reviews_0433.csv (143 rows)
# Loaded gojek_reviews_0434.csv (137 rows)
# Loaded gojek_reviews_0435.csv (130 rows)
# Loaded gojek_reviews_0436.csv (125 rows)
# Loaded gojek_reviews_0437.csv (133 rows)
# Loaded gojek_reviews_0438.csv (126 rows)
# Loaded gojek_reviews_0439.csv (139 rows)
# Loaded gojek_reviews_0440.csv (137 rows)
# Loaded gojek_reviews_0441.csv (146 rows)
# Loaded gojek_reviews_0442.csv (138 rows)
# Loaded gojek_reviews_0443.csv (124 rows)
# Loaded gojek_reviews_0444.csv (142 rows)
# Loaded gojek_reviews_0445.csv (138 rows)
# Loaded gojek_reviews_0446.csv (136 rows)
# Loaded gojek_reviews_0447.csv (128 rows)
# Loaded gojek_reviews_0448.csv (133 rows)
# Loaded gojek_reviews_0449.csv (147 rows)
# Loaded gojek_reviews_0450.csv (139 rows)
# Loaded gojek_reviews_0451.csv (132 rows)
# Loaded gojek_reviews_0452.csv (149 rows)
# Loaded gojek_reviews_0453.csv (131 rows)
# Loaded gojek_reviews_0454.csv (121 rows)
# Loaded gojek_reviews_0455.csv (138 rows)
# Loaded gojek_reviews_0456.csv (141 rows)
# Loaded gojek_reviews_0457.csv (134 rows)
# Loaded gojek_reviews_0458.csv (149 rows)
# Loaded gojek_reviews_0459.csv (136 rows)
# Loaded gojek_reviews_0460.csv (143 rows)
# Loaded gojek_reviews_0461.csv (137 rows)
# Loaded gojek_reviews_0462.csv (142 rows)
# Loaded gojek_reviews_0463.csv (139 rows)
# Loaded gojek_reviews_0464.csv (129 rows)
# Loaded gojek_reviews_0465.csv (131 rows)
# Loaded gojek_reviews_0466.csv (136 rows)
# Loaded gojek_reviews_0467.csv (155 rows)
# Loaded gojek_reviews_0468.csv (132 rows)
# Loaded gojek_reviews_0469.csv (125 rows)
# Loaded gojek_reviews_0470.csv (136 rows)
# Loaded gojek_reviews_0471.csv (144 rows)
# Loaded gojek_reviews_0472.csv (131 rows)
# Loaded gojek_reviews_0473.csv (135 rows)
# Loaded gojek_reviews_0474.csv (129 rows)
# Loaded gojek_reviews_0475.csv (134 rows)
# Loaded gojek_reviews_0476.csv (150 rows)
# Loaded gojek_reviews_0477.csv (134 rows)
# Loaded gojek_reviews_0478.csv (146 rows)
# Loaded gojek_reviews_0479.csv (141 rows)
# Loaded gojek_reviews_0480.csv (134 rows)
# Loaded gojek_reviews_0481.csv (146 rows)
# Loaded gojek_reviews_0482.csv (143 rows)
# Loaded gojek_reviews_0483.csv (136 rows)
# Loaded gojek_reviews_0484.csv (149 rows)
# Loaded gojek_reviews_0485.csv (141 rows)
# Loaded gojek_reviews_0486.csv (147 rows)
# Loaded gojek_reviews_0487.csv (135 rows)
# Loaded gojek_reviews_0488.csv (148 rows)
# Loaded gojek_reviews_0489.csv (158 rows)
# Loaded gojek_reviews_0490.csv (149 rows)
# Loaded gojek_reviews_0491.csv (146 rows)
# Loaded gojek_reviews_0492.csv (146 rows)
# Loaded gojek_reviews_0493.csv (140 rows)
# Loaded gojek_reviews_0494.csv (139 rows)
# Loaded gojek_reviews_0495.csv (147 rows)
# Loaded gojek_reviews_0496.csv (147 rows)
# Loaded gojek_reviews_0497.csv (142 rows)
# Loaded gojek_reviews_0498.csv (147 rows)
# Loaded gojek_reviews_0499.csv (138 rows)
# Loaded gojek_reviews_0500.csv (140 rows)
# Loaded gojek_reviews_0501.csv (147 rows)
# Loaded gojek_reviews_0502.csv (147 rows)
# Loaded gojek_reviews_0503.csv (134 rows)
# Loaded gojek_reviews_0504.csv (144 rows)
# Loaded gojek_reviews_0505.csv (132 rows)
# Loaded gojek_reviews_0506.csv (139 rows)
# Loaded gojek_reviews_0507.csv (133 rows)
# Loaded gojek_reviews_0508.csv (153 rows)
# Loaded gojek_reviews_0509.csv (147 rows)
# Loaded gojek_reviews_0510.csv (148 rows)
# Loaded gojek_reviews_0511.csv (143 rows)
# Loaded gojek_reviews_0512.csv (135 rows)
# Loaded gojek_reviews_0513.csv (142 rows)
# Loaded gojek_reviews_0514.csv (149 rows)
# Loaded gojek_reviews_0515.csv (132 rows)
# Loaded gojek_reviews_0516.csv (146 rows)
# Loaded gojek_reviews_0517.csv (143 rows)
# Loaded gojek_reviews_0518.csv (150 rows)
# Loaded gojek_reviews_0519.csv (143 rows)
# Loaded gojek_reviews_0520.csv (125 rows)
# Loaded gojek_reviews_0521.csv (145 rows)
# Loaded gojek_reviews_0522.csv (140 rows)
# Loaded gojek_reviews_0523.csv (137 rows)
# Loaded gojek_reviews_0524.csv (144 rows)
# Loaded gojek_reviews_0525.csv (148 rows)
# Loaded gojek_reviews_0526.csv (139 rows)
# Loaded gojek_reviews_0527.csv (142 rows)
# Loaded gojek_reviews_0528.csv (130 rows)
# Loaded gojek_reviews_0529.csv (151 rows)
# Loaded gojek_reviews_0530.csv (147 rows)
# Loaded gojek_reviews_0531.csv (138 rows)
# Loaded gojek_reviews_0532.csv (138 rows)
# Loaded gojek_reviews_0533.csv (126 rows)
# Loaded gojek_reviews_0534.csv (151 rows)
# Loaded gojek_reviews_0535.csv (152 rows)
# Loaded gojek_reviews_0536.csv (153 rows)
# Loaded gojek_reviews_0537.csv (138 rows)
# Loaded gojek_reviews_0538.csv (136 rows)
# Loaded gojek_reviews_0539.csv (144 rows)
# Loaded gojek_reviews_0540.csv (137 rows)
# Loaded gojek_reviews_0541.csv (140 rows)
# Loaded gojek_reviews_0542.csv (145 rows)
# Loaded gojek_reviews_0543.csv (134 rows)
# Loaded gojek_reviews_0544.csv (143 rows)
# Loaded gojek_reviews_0545.csv (132 rows)
# Loaded gojek_reviews_0546.csv (143 rows)
# Loaded gojek_reviews_0547.csv (140 rows)
# Loaded gojek_reviews_0548.csv (147 rows)
# Loaded gojek_reviews_0549.csv (131 rows)
# Loaded gojek_reviews_0550.csv (147 rows)
# Loaded gojek_reviews_0551.csv (128 rows)
# Loaded gojek_reviews_0552.csv (127 rows)
# Loaded gojek_reviews_0553.csv (140 rows)
# Loaded gojek_reviews_0554.csv (138 rows)
# Loaded gojek_reviews_0555.csv (131 rows)
# Loaded gojek_reviews_0556.csv (147 rows)
# Loaded gojek_reviews_0557.csv (140 rows)
# Loaded gojek_reviews_0558.csv (120 rows)
# Loaded gojek_reviews_0559.csv (136 rows)
# Loaded gojek_reviews_0560.csv (133 rows)
# Loaded gojek_reviews_0561.csv (147 rows)
# Loaded gojek_reviews_0562.csv (149 rows)
# Loaded gojek_reviews_0563.csv (138 rows)
# Loaded gojek_reviews_0564.csv (137 rows)
# Loaded gojek_reviews_0565.csv (130 rows)
# Loaded gojek_reviews_0566.csv (145 rows)
# Loaded gojek_reviews_0567.csv (129 rows)
# Loaded gojek_reviews_0568.csv (135 rows)
# Loaded gojek_reviews_0569.csv (133 rows)
# Loaded gojek_reviews_0570.csv (142 rows)
# Loaded gojek_reviews_0571.csv (142 rows)
# Loaded gojek_reviews_0572.csv (142 rows)
# Loaded gojek_reviews_0573.csv (145 rows)
# Loaded gojek_reviews_0574.csv (143 rows)
# Loaded gojek_reviews_0575.csv (133 rows)
# Loaded gojek_reviews_0576.csv (129 rows)
# Loaded gojek_reviews_0577.csv (140 rows)
# Loaded gojek_reviews_0578.csv (140 rows)
# Loaded gojek_reviews_0579.csv (146 rows)
# Loaded gojek_reviews_0580.csv (133 rows)
# Loaded gojek_reviews_0581.csv (138 rows)
# Loaded gojek_reviews_0582.csv (133 rows)
# Loaded gojek_reviews_0583.csv (148 rows)
# Loaded gojek_reviews_0584.csv (139 rows)
# Loaded gojek_reviews_0585.csv (122 rows)
# Loaded gojek_reviews_0586.csv (142 rows)
# Loaded gojek_reviews_0587.csv (131 rows)
# Loaded gojek_reviews_0588.csv (134 rows)
# Loaded gojek_reviews_0589.csv (139 rows)
# Loaded gojek_reviews_0590.csv (142 rows)
# Loaded gojek_reviews_0591.csv (132 rows)
# Loaded gojek_reviews_0592.csv (127 rows)
# Loaded gojek_reviews_0593.csv (144 rows)
# Loaded gojek_reviews_0594.csv (139 rows)
# Loaded gojek_reviews_0595.csv (135 rows)
# Loaded gojek_reviews_0596.csv (135 rows)
# Loaded gojek_reviews_0597.csv (141 rows)
# Loaded gojek_reviews_0598.csv (136 rows)
# Loaded gojek_reviews_0599.csv (148 rows)
# Loaded gojek_reviews_0600.csv (131 rows)
# Loaded gojek_reviews_0601.csv (130 rows)
# Loaded gojek_reviews_0602.csv (139 rows)
# Loaded gojek_reviews_0603.csv (136 rows)
# Loaded gojek_reviews_0604.csv (131 rows)
# Loaded gojek_reviews_0605.csv (143 rows)
# Loaded gojek_reviews_0606.csv (142 rows)
# Loaded gojek_reviews_0607.csv (138 rows)
# Loaded gojek_reviews_0608.csv (131 rows)
# Loaded gojek_reviews_0609.csv (142 rows)
# Loaded gojek_reviews_0610.csv (126 rows)
# Loaded gojek_reviews_0611.csv (131 rows)
# Loaded gojek_reviews_0612.csv (139 rows)
# Loaded gojek_reviews_0613.csv (150 rows)
# Loaded gojek_reviews_0614.csv (136 rows)
# Loaded gojek_reviews_0615.csv (147 rows)
# Loaded gojek_reviews_0616.csv (154 rows)
# Loaded gojek_reviews_0617.csv (145 rows)
# Loaded gojek_reviews_0618.csv (138 rows)
# Loaded gojek_reviews_0619.csv (141 rows)
# Loaded gojek_reviews_0620.csv (131 rows)
# Loaded gojek_reviews_0621.csv (120 rows)
# Loaded gojek_reviews_0622.csv (141 rows)
# Loaded gojek_reviews_0623.csv (130 rows)
# Loaded gojek_reviews_0624.csv (138 rows)
# Loaded gojek_reviews_0625.csv (133 rows)
# Loaded gojek_reviews_0626.csv (146 rows)
# Loaded gojek_reviews_0627.csv (141 rows)
# Loaded gojek_reviews_0628.csv (129 rows)
# Loaded gojek_reviews_0629.csv (138 rows)
# Loaded gojek_reviews_0630.csv (149 rows)
# Loaded gojek_reviews_0631.csv (139 rows)
# Loaded gojek_reviews_0632.csv (143 rows)
# Loaded gojek_reviews_0633.csv (137 rows)
# Loaded gojek_reviews_0634.csv (142 rows)
# Loaded gojek_reviews_0635.csv (146 rows)
# Loaded gojek_reviews_0636.csv (148 rows)
# Loaded gojek_reviews_0637.csv (135 rows)
# Loaded gojek_reviews_0638.csv (143 rows)
# Loaded gojek_reviews_0639.csv (137 rows)
# Loaded gojek_reviews_0640.csv (138 rows)
# Loaded gojek_reviews_0641.csv (135 rows)
# Loaded gojek_reviews_0642.csv (151 rows)
# Loaded gojek_reviews_0643.csv (145 rows)
# Loaded gojek_reviews_0644.csv (145 rows)
# Loaded gojek_reviews_0645.csv (140 rows)
# Loaded gojek_reviews_0646.csv (135 rows)
# Loaded gojek_reviews_0647.csv (138 rows)
# Loaded gojek_reviews_0648.csv (141 rows)
# Loaded gojek_reviews_0649.csv (132 rows)
# Loaded gojek_reviews_0650.csv (141 rows)
# Loaded gojek_reviews_0651.csv (147 rows)
# Loaded gojek_reviews_0652.csv (130 rows)
# Loaded gojek_reviews_0653.csv (149 rows)
# Loaded gojek_reviews_0654.csv (143 rows)
# Loaded gojek_reviews_0655.csv (142 rows)
# Loaded gojek_reviews_0656.csv (135 rows)
# Loaded gojek_reviews_0657.csv (125 rows)
# Loaded gojek_reviews_0658.csv (142 rows)
# Loaded gojek_reviews_0659.csv (137 rows)
# Loaded gojek_reviews_0660.csv (149 rows)
# Loaded gojek_reviews_0661.csv (142 rows)
# Loaded gojek_reviews_0662.csv (148 rows)
# Loaded gojek_reviews_0663.csv (137 rows)
# Loaded gojek_reviews_0664.csv (142 rows)
# Loaded gojek_reviews_0665.csv (138 rows)
# Loaded gojek_reviews_0666.csv (142 rows)
# Loaded gojek_reviews_0667.csv (144 rows)
# Loaded gojek_reviews_0668.csv (141 rows)
# Loaded gojek_reviews_0669.csv (139 rows)
# Loaded gojek_reviews_0670.csv (129 rows)
# Loaded gojek_reviews_0671.csv (138 rows)
# Loaded gojek_reviews_0672.csv (137 rows)
# Loaded gojek_reviews_0673.csv (140 rows)
# Loaded gojek_reviews_0674.csv (142 rows)
# Loaded gojek_reviews_0675.csv (136 rows)
# Loaded gojek_reviews_0676.csv (140 rows)
# Loaded gojek_reviews_0677.csv (146 rows)
# Loaded gojek_reviews_0678.csv (141 rows)
# Loaded gojek_reviews_0679.csv (138 rows)
# Loaded gojek_reviews_0680.csv (140 rows)
# Loaded gojek_reviews_0681.csv (142 rows)
# Loaded gojek_reviews_0682.csv (140 rows)
# Loaded gojek_reviews_0683.csv (156 rows)
# Loaded gojek_reviews_0684.csv (141 rows)
# Loaded gojek_reviews_0685.csv (153 rows)
# Loaded gojek_reviews_0686.csv (147 rows)
# Loaded gojek_reviews_0687.csv (140 rows)
# Loaded gojek_reviews_0688.csv (137 rows)
# Loaded gojek_reviews_0689.csv (135 rows)
# Loaded gojek_reviews_0690.csv (146 rows)
# Loaded gojek_reviews_0691.csv (134 rows)
# Loaded gojek_reviews_0692.csv (143 rows)
# Loaded gojek_reviews_0693.csv (131 rows)
# Loaded gojek_reviews_0694.csv (126 rows)
# Loaded gojek_reviews_0695.csv (134 rows)
# Loaded gojek_reviews_0696.csv (144 rows)
# Loaded gojek_reviews_0697.csv (144 rows)
# Loaded gojek_reviews_0698.csv (133 rows)
# Loaded gojek_reviews_0699.csv (154 rows)
# Loaded gojek_reviews_0700.csv (131 rows)
# Loaded gojek_reviews_0701.csv (137 rows)
# Loaded gojek_reviews_0702.csv (139 rows)
# Loaded gojek_reviews_0703.csv (150 rows)
# Loaded gojek_reviews_0704.csv (135 rows)
# Loaded gojek_reviews_0705.csv (139 rows)
# Loaded gojek_reviews_0706.csv (143 rows)
# Loaded gojek_reviews_0707.csv (149 rows)
# Loaded gojek_reviews_0708.csv (139 rows)
# Loaded gojek_reviews_0709.csv (129 rows)
# Loaded gojek_reviews_0710.csv (133 rows)
# Loaded gojek_reviews_0711.csv (147 rows)
# Loaded gojek_reviews_0712.csv (146 rows)
# Loaded gojek_reviews_0713.csv (139 rows)
# Loaded gojek_reviews_0714.csv (150 rows)
# Loaded gojek_reviews_0715.csv (151 rows)
# Loaded gojek_reviews_0716.csv (149 rows)
# Loaded gojek_reviews_0717.csv (137 rows)
# Loaded gojek_reviews_0718.csv (134 rows)
# Loaded gojek_reviews_0719.csv (140 rows)
# Loaded gojek_reviews_0720.csv (142 rows)
# Loaded gojek_reviews_0721.csv (146 rows)
# Loaded gojek_reviews_0722.csv (136 rows)
# Loaded gojek_reviews_0723.csv (147 rows)
# Loaded gojek_reviews_0724.csv (146 rows)
# Loaded gojek_reviews_0725.csv (140 rows)
# Loaded gojek_reviews_0726.csv (137 rows)
# Loaded gojek_reviews_0727.csv (144 rows)
#
# Merged 728 batches → ../data/gojek_reviews_full.csv
# Total unique reviews: 100,127
